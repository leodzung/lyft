# %% [markdown]
# # Lyft: Complete train and prediction pipeline (update for l5kit 1.1.0)
#
# ![](http://www.l5kit.org/_images/av.jpg)
# <cite>The image from L5Kit official document: <a href="http://www.l5kit.org/README.html">http://www.l5kit.org/README.html</a></cite>
#
# #### This notebook is updated to be compatible with the new lyft environment, see the discussion [We did it all wrong](https://www.kaggle.com/c/lyft-motion-prediction-autonomous-vehicles/discussion/186492) and [l5kit 1.1.0 release](https://www.kaggle.com/c/lyft-motion-prediction-autonomous-vehicles/discussion/187825).
#
# For a high level overview, check out this article [how to build a motion prediction model for autonomous vehicles](https://medium.com/lyftlevel5/how-to-build-a-motion-prediction-model-for-autonomous-vehicles-29f7f81f1580).
#
# In this notebook I present an **end-to-end** train and prediction pipeline to predict vehicle motions with a pretrained model included. Unfortunately because of Kaggle memory constraint we can only either run the train part or the prediction part by toggling the parameters in the config part.
#
# Some of the code here are taken from the [tutorial notebook](https://github.com/lyft/l5kit/tree/master/examples/agent_motion_prediction) and the following kernels:
#
# - [Lyft: Training with multi-mode confidence](https://www.kaggle.com/corochann/lyft-training-with-multi-mode-confidence)
# - [Lyft: Prediction with multi-mode confidence](https://www.kaggle.com/corochann/lyft-prediction-with-multi-mode-confidence)
#
# which is part of a wonderful series of introductory notebooks by [corochann](https://www.kaggle.com/corochann)
#
#  - [Lyft: Comprehensive guide to start competition](https://www.kaggle.com/corochann/lyft-comprehensive-guide-to-start-competition)
#  - [Lyft: Deep into the l5kit library](https://www.kaggle.com/corochann/lyft-deep-into-the-l5kit-library)
#  - [Save your time, submit without kernel inference](https://www.kaggle.com/corochann/save-your-time-submit-without-kernel-inference)
#  - [Lyft: pytorch implementation of evaluation metric](https://www.kaggle.com/corochann/lyft-pytorch-implementation-of-evaluation-metric)
#  - [Lyft: Training with multi-mode confidence](https://www.kaggle.com/corochann/lyft-training-with-multi-mode-confidence)
#  - [Lyft: Prediction with multi-mode confidence](https://www.kaggle.com/corochann/lyft-prediction-with-multi-mode-confidence)
#
# **Note:** This notebook aims to create the best single possible, i.e. without any ensemeble, which should only be done near the end of the competition. Since it is still early in the competition, this notebook is still a baseline, any suggestion to improve is appreciated.

# %%
# mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os 

os.makedirs('/content/lyft-motion-prediction-autonomous-vehicles/', exist_ok=True)
os.chdir('/content/lyft-motion-prediction-autonomous-vehicles/')

# %cd '/content/lyft-motion-prediction-autonomous-vehicles/'
# !pwd
# Out:
# /content
# /content/lyft-motion-prediction-autonomous-vehicles

# %%
os.makedirs('/content/lyft-motion-prediction-autonomous-vehicles/scenes/', exist_ok=True)
os.chdir('/content/lyft-motion-prediction-autonomous-vehicles/scenes/')

# !wget --header="Host: storage.googleapis.com" --header="User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9" --header="Accept-Language: en-US,en;q=0.9,vi-VN;q=0.8,vi;q=0.7" --header="Referer: https://www.kaggle.com/" "https://storage.googleapis.com/kaggle-competitions-data/kaggle-v2/19990/1472735/compressed/scenes.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1603023114&Signature=YXhIEGU4TQ3MQ%2FSJoniO%2BdpiXyhmbRAWVWqCaMI6F%2Bq7VZpJMNYBENSZK1WEgIGGSW077G1ytTx1vzOsSruRCWvhD2LpWn5O9Coa9MdNMkcpAcQp9cOhExT7cnVjDFfbCQenehnr3O51KpxSOSekq00mZW7VV1LEi6t1ccosOMBPK4Vn82D9Kqoj6WuHaN%2FfZ6COGUQWZg3bR1ou%2Bp2%2BM6kyPfgIiA6ceAzBvNGougiQPDeIphOv4HXqC9MtRyAmES8dwkx3xM4kDmos14CtpFGXYb2Xc9%2FYW56uJd%2BdASAM7L8y4PNIiHiUlsv6d0rc%2BLi3t4FIv%2BHM3iJnBz8J6g%3D%3D&response-content-disposition=attachment%3B+filename%3Dscenes.zip" -c -O 'scenes.zip'
# !unzip ./scenes.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: validate.zarr/agents_mask/0.5/8502.0
#   inflating: validate.zarr/agents_mask/0.5/8503.0
#   inflating: validate.zarr/agents_mask/0.5/8504.0
#   inflating: validate.zarr/agents_mask/0.5/8505.0
#   inflating: validate.zarr/agents_mask/0.5/8506.0
#   inflating: validate.zarr/agents_mask/0.5/8507.0
#   inflating: validate.zarr/agents_mask/0.5/8508.0
#   inflating: validate.zarr/agents_mask/0.5/8509.0
#   inflating: validate.zarr/agents_mask/0.5/851.0
#   inflating: validate.zarr/agents_mask/0.5/8510.0
#   inflating: validate.zarr/agents_mask/0.5/8511.0
#   inflating: validate.zarr/agents_mask/0.5/8512.0
#   inflating: validate.zarr/agents_mask/0.5/8513.0
#   inflating: validate.zarr/agents_mask/0.5/8514.0
#   inflating: validate.zarr/agents_mask/0.5/8515.0
#   inflating: validate.zarr/agents_mask/0.5/8516.0
#   inflating: validate.zarr/agents_mask/0.5/8517.0
#   inflating: validate.zarr/agents_mask/0.5/8518.0
#   inflating: validate.zarr/agents_mask/0.5/8519.0
#   inflating: validate.zarr/agents_mask/0.5/852.0
#   inflating: validate.zarr/agents_mask/0.5/8520.0
#   inflating: validate.zarr/agents_mask/0.5/8521.0
#   inflating: validate.zarr/agents_mask/0.5/8522.0
#   inflating: validate.zarr/agents_mask/0.5/8523.0
#   inflating: validate.zarr/agents_mask/0.5/8524.0
#   inflating: validate.zarr/agents_mask/0.5/8525.0
#   inflating: validate.zarr/agents_mask/0.5/8526.0
#   inflating: validate.zarr/agents_mask/0.5/8527.0
#   inflating: validate.zarr/agents_mask/0.5/8528.0
#   inflating: validate.zarr/agents_mask/0.5/8529.0
#   inflating: validate.zarr/agents_mask/0.5/853.0
#   inflating: validate.zarr/agents_mask/0.5/8530.0
#   inflating: validate.zarr/agents_mask/0.5/8531.0
#   inflating: validate.zarr/agents_mask/0.5/8532.0
#   inflating: validate.zarr/agents_mask/0.5/8533.0
#   inflating: validate.zarr/agents_mask/0.5/8534.0
#   inflating: validate.zarr/agents_mask/0.5/8535.0
#   inflating: validate.zarr/agents_mask/0.5/8536.0
#   inflating: validate.zarr/agents_mask/0.5/8537.0
#   inflating: validate.zarr/agents_mask/0.5/8538.0
#   inflating: validate.zarr/agents_mask/0.5/8539.0
#   inflating: validate.zarr/agents_mask/0.5/854.0
#   inflating: validate.zarr/agents_mask/0.5/8540.0
#   inflating: validate.zarr/agents_mask/0.5/8541.0
#   inflating: validate.zarr/agents_mask/0.5/8542.0
#   inflating: validate.zarr/agents_mask/0.5/8543.0
#   inflating: validate.zarr/agents_mask/0.5/8544.0
#   inflating: validate.zarr/agents_mask/0.5/8545.0
#   inflating: validate.zarr/agents_mask/0.5/8546.0
#   inflating: validate.zarr/agents_mask/0.5/8547.0
#   inflating: validate.zarr/agents_mask/0.5/8548.0
#   inflating: validate.zarr/agents_mask/0.5/8549.0
#   inflating: validate.zarr/agents_mask/0.5/855.0
#   inflating: validate.zarr/agents_mask/0.5/8550.0
#   inflating: validate.zarr/agents_mask/0.5/8551.0
#   inflating: validate.zarr/agents_mask/0.5/8552.0
#   inflating: validate.zarr/agents_mask/0.5/8553.0
#   inflating: validate.zarr/agents_mask/0.5/8554.0
#   inflating: validate.zarr/agents_mask/0.5/8555.0
#   inflating: validate.zarr/agents_mask/0.5/8556.0
#   inflating: validate.zarr/agents_mask/0.5/8557.0
#   inflating: validate.zarr/agents_mask/0.5/8558.0
#   inflating: validate.zarr/agents_mask/0.5/8559.0
#   inflating: validate.zarr/agents_mask/0.5/856.0
#   inflating: validate.zarr/agents_mask/0.5/8560.0
#   inflating: validate.zarr/agents_mask/0.5/8561.0
#   inflating: validate.zarr/agents_mask/0.5/8562.0
#   inflating: validate.zarr/agents_mask/0.5/8563.0
#   inflating: validate.zarr/agents_mask/0.5/8564.0
#   inflating: validate.zarr/agents_mask/0.5/8565.0
#   inflating: validate.zarr/agents_mask/0.5/8566.0
#   inflating: validate.zarr/agents_mask/0.5/8567.0
#   inflating: validate.zarr/agents_mask/0.5/8568.0
#   inflating: validate.zarr/agents_mask/0.5/8569.0
#   inflating: validate.zarr/agents_mask/0.5/857.0
#   inflating: validate.zarr/agents_mask/0.5/8570.0
#   inflating: validate.zarr/agents_mask/0.5/8571.0
#   inflating: validate.zarr/agents_mask/0.5/8572.0
#   inflating: validate.zarr/agents_mask/0.5/8573.0
#   inflating: validate.zarr/agents_mask/0.5/8574.0
#   inflating: validate.zarr/agents_mask/0.5/8575.0
#   inflating: validate.zarr/agents_mask/0.5/8576.0
#   inflating: validate.zarr/agents_mask/0.5/8577.0
#   inflating: validate.zarr/agents_mask/0.5/8578.0
#   inflating: validate.zarr/agents_mask/0.5/8579.0
#   inflating: validate.zarr/agents_mask/0.5/858.0
#   inflating: validate.zarr/agents_mask/0.5/8580.0
#   inflating: validate.zarr/agents_mask/0.5/8581.0
#   inflating: validate.zarr/agents_mask/0.5/8582.0
#   inflating: validate.zarr/agents_mask/0.5/8583.0
#   inflating: validate.zarr/agents_mask/0.5/8584.0
#   inflating: validate.zarr/agents_mask/0.5/8585.0
#   inflating: validate.zarr/agents_mask/0.5/8586.0
#   inflating: validate.zarr/agents_mask/0.5/8587.0
#   inflating: validate.zarr/agents_mask/0.5/8588.0
#   inflating: validate.zarr/agents_mask/0.5/8589.0
#   inflating: validate.zarr/agents_mask/0.5/859.0
#   inflating: validate.zarr/agents_mask/0.5/8590.0
#   inflating: validate.zarr/agents_mask/0.5/8591.0
#   inflating: validate.zarr/agents_mask/0.5/8592.0
#   inflating: validate.zarr/agents_mask/0.5/8593.0
#   inflating: validate.zarr/agents_mask/0.5/8594.0
#   inflating: validate.zarr/agents_mask/0.5/8595.0
#   inflating: validate.zarr/agents_mask/0.5/8596.0
#   inflating: validate.zarr/agents_mask/0.5/8597.0
#   inflating: validate.zarr/agents_mask/0.5/8598.0
#   inflating: validate.zarr/agents_mask/0.5/8599.0
#   inflating: validate.zarr/agents_mask/0.5/86.0
#   inflating: validate.zarr/agents_mask/0.5/860.0
#   inflating: validate.zarr/agents_mask/0.5/8600.0
#   inflating: validate.zarr/agents_mask/0.5/8601.0
#   inflating: validate.zarr/agents_mask/0.5/8602.0
#   inflating: validate.zarr/agents_mask/0.5/8603.0
#   inflating: validate.zarr/agents_mask/0.5/8604.0
#   inflating: validate.zarr/agents_mask/0.5/8605.0
#   inflating: validate.zarr/agents_mask/0.5/8606.0
#   inflating: validate.zarr/agents_mask/0.5/8607.0
#   inflating: validate.zarr/agents_mask/0.5/8608.0
#   inflating: validate.zarr/agents_mask/0.5/8609.0
#   inflating: validate.zarr/agents_mask/0.5/861.0
#   inflating: validate.zarr/agents_mask/0.5/8610.0
#   inflating: validate.zarr/agents_mask/0.5/8611.0
#   inflating: validate.zarr/agents_mask/0.5/8612.0
#   inflating: validate.zarr/agents_mask/0.5/8613.0
#   inflating: validate.zarr/agents_mask/0.5/8614.0
#   inflating: validate.zarr/agents_mask/0.5/8615.0
#   inflating: validate.zarr/agents_mask/0.5/8616.0
#   inflating: validate.zarr/agents_mask/0.5/8617.0
#   inflating: validate.zarr/agents_mask/0.5/8618.0
#   inflating: validate.zarr/agents_mask/0.5/8619.0
#   inflating: validate.zarr/agents_mask/0.5/862.0
#   inflating: validate.zarr/agents_mask/0.5/8620.0
#   inflating: validate.zarr/agents_mask/0.5/8621.0
#   inflating: validate.zarr/agents_mask/0.5/8622.0
#   inflating: validate.zarr/agents_mask/0.5/8623.0
#   inflating: validate.zarr/agents_mask/0.5/8624.0
#   inflating: validate.zarr/agents_mask/0.5/8625.0
#   inflating: validate.zarr/agents_mask/0.5/8626.0
#   inflating: validate.zarr/agents_mask/0.5/8627.0
#   inflating: validate.zarr/agents_mask/0.5/8628.0
#   inflating: validate.zarr/agents_mask/0.5/8629.0
#   inflating: validate.zarr/agents_mask/0.5/863.0
#   inflating: validate.zarr/agents_mask/0.5/8630.0
#   inflating: validate.zarr/agents_mask/0.5/8631.0
#   inflating: validate.zarr/agents_mask/0.5/8632.0
#   inflating: validate.zarr/agents_mask/0.5/8633.0
#   inflating: validate.zarr/agents_mask/0.5/8634.0
#   inflating: validate.zarr/agents_mask/0.5/8635.0
#   inflating: validate.zarr/agents_mask/0.5/8636.0
#   inflating: validate.zarr/agents_mask/0.5/8637.0
#   inflating: validate.zarr/agents_mask/0.5/8638.0
#   inflating: validate.zarr/agents_mask/0.5/8639.0
#   inflating: validate.zarr/agents_mask/0.5/864.0
#   inflating: validate.zarr/agents_mask/0.5/8640.0
#   inflating: validate.zarr/agents_mask/0.5/8641.0
#   inflating: validate.zarr/agents_mask/0.5/8642.0
#   inflating: validate.zarr/agents_mask/0.5/8643.0
#   inflating: validate.zarr/agents_mask/0.5/8644.0
#   inflating: validate.zarr/agents_mask/0.5/8645.0
#   inflating: validate.zarr/agents_mask/0.5/8646.0
#   inflating: validate.zarr/agents_mask/0.5/8647.0
#   inflating: validate.zarr/agents_mask/0.5/8648.0
#   inflating: validate.zarr/agents_mask/0.5/8649.0
#   inflating: validate.zarr/agents_mask/0.5/865.0
#   inflating: validate.zarr/agents_mask/0.5/8650.0
#   inflating: validate.zarr/agents_mask/0.5/8651.0
#   inflating: validate.zarr/agents_mask/0.5/8652.0
#   inflating: validate.zarr/agents_mask/0.5/8653.0
#   inflating: validate.zarr/agents_mask/0.5/8654.0
#   inflating: validate.zarr/agents_mask/0.5/8655.0
#   inflating: validate.zarr/agents_mask/0.5/8656.0
#   inflating: validate.zarr/agents_mask/0.5/8657.0
#   inflating: validate.zarr/agents_mask/0.5/8658.0
#   inflating: validate.zarr/agents_mask/0.5/8659.0
#   inflating: validate.zarr/agents_mask/0.5/866.0
#   inflating: validate.zarr/agents_mask/0.5/8660.0
#   inflating: validate.zarr/agents_mask/0.5/8661.0
#   inflating: validate.zarr/agents_mask/0.5/8662.0
#   inflating: validate.zarr/agents_mask/0.5/8663.0
#   inflating: validate.zarr/agents_mask/0.5/8664.0
#   inflating: validate.zarr/agents_mask/0.5/8665.0
#   inflating: validate.zarr/agents_mask/0.5/8666.0
#   inflating: validate.zarr/agents_mask/0.5/8667.0
#   inflating: validate.zarr/agents_mask/0.5/8668.0
#   inflating: validate.zarr/agents_mask/0.5/8669.0
#   inflating: validate.zarr/agents_mask/0.5/867.0
#   inflating: validate.zarr/agents_mask/0.5/8670.0
#   inflating: validate.zarr/agents_mask/0.5/8671.0
#   inflating: validate.zarr/agents_mask/0.5/8672.0
#   inflating: validate.zarr/agents_mask/0.5/8673.0
#   inflating: validate.zarr/agents_mask/0.5/8674.0
#   inflating: validate.zarr/agents_mask/0.5/8675.0
#   inflating: validate.zarr/agents_mask/0.5/8676.0
#   inflating: validate.zarr/agents_mask/0.5/8677.0
#   inflating: validate.zarr/agents_mask/0.5/8678.0
#   inflating: validate.zarr/agents_mask/0.5/8679.0
#   inflating: validate.zarr/agents_mask/0.5/868.0
#   inflating: validate.zarr/agents_mask/0.5/8680.0
#   inflating: validate.zarr/agents_mask/0.5/8681.0
#   inflating: validate.zarr/agents_mask/0.5/8682.0
#   inflating: validate.zarr/agents_mask/0.5/8683.0
#   inflating: validate.zarr/agents_mask/0.5/8684.0
#   inflating: validate.zarr/agents_mask/0.5/8685.0
#   inflating: validate.zarr/agents_mask/0.5/8686.0
#   inflating: validate.zarr/agents_mask/0.5/8687.0
#   inflating: validate.zarr/agents_mask/0.5/8688.0
#   inflating: validate.zarr/agents_mask/0.5/8689.0
#   inflating: validate.zarr/agents_mask/0.5/869.0
#   inflating: validate.zarr/agents_mask/0.5/8690.0
#   inflating: validate.zarr/agents_mask/0.5/8691.0
#   inflating: validate.zarr/agents_mask/0.5/8692.0
#   inflating: validate.zarr/agents_mask/0.5/8693.0
#   inflating: validate.zarr/agents_mask/0.5/8694.0
#   inflating: validate.zarr/agents_mask/0.5/8695.0
#   inflating: validate.zarr/agents_mask/0.5/8696.0
#   inflating: validate.zarr/agents_mask/0.5/8697.0
#   inflating: validate.zarr/agents_mask/0.5/8698.0
#   inflating: validate.zarr/agents_mask/0.5/8699.0
#   inflating: validate.zarr/agents_mask/0.5/87.0
#   inflating: validate.zarr/agents_mask/0.5/870.0
#   inflating: validate.zarr/agents_mask/0.5/8700.0
#   inflating: validate.zarr/agents_mask/0.5/8701.0
#   inflating: validate.zarr/agents_mask/0.5/8702.0
#   inflating: validate.zarr/agents_mask/0.5/8703.0
#   inflating: validate.zarr/agents_mask/0.5/8704.0
#   inflating: validate.zarr/agents_mask/0.5/8705.0
#   inflating: validate.zarr/agents_mask/0.5/8706.0
#   inflating: validate.zarr/agents_mask/0.5/8707.0
#   inflating: validate.zarr/agents_mask/0.5/8708.0
#   inflating: validate.zarr/agents_mask/0.5/8709.0
#   inflating: validate.zarr/agents_mask/0.5/871.0
#   inflating: validate.zarr/agents_mask/0.5/8710.0
#   inflating: validate.zarr/agents_mask/0.5/8711.0
#   inflating: validate.zarr/agents_mask/0.5/8712.0
#   inflating: validate.zarr/agents_mask/0.5/8713.0
#   inflating: validate.zarr/agents_mask/0.5/8714.0
#   inflating: validate.zarr/agents_mask/0.5/8715.0
#   inflating: validate.zarr/agents_mask/0.5/8716.0
#   inflating: validate.zarr/agents_mask/0.5/8717.0
#   inflating: validate.zarr/agents_mask/0.5/8718.0
#   inflating: validate.zarr/agents_mask/0.5/8719.0
#   inflating: validate.zarr/agents_mask/0.5/872.0
#   inflating: validate.zarr/agents_mask/0.5/8720.0
#   inflating: validate.zarr/agents_mask/0.5/8721.0
#   inflating: validate.zarr/agents_mask/0.5/8722.0
#   inflating: validate.zarr/agents_mask/0.5/8723.0
#   inflating: validate.zarr/agents_mask/0.5/8724.0
#   inflating: validate.zarr/agents_mask/0.5/8725.0
#   inflating: validate.zarr/agents_mask/0.5/8726.0
#   inflating: validate.zarr/agents_mask/0.5/8727.0
#   inflating: validate.zarr/agents_mask/0.5/8728.0
#   inflating: validate.zarr/agents_mask/0.5/8729.0
#   inflating: validate.zarr/agents_mask/0.5/873.0
#   inflating: validate.zarr/agents_mask/0.5/8730.0
#   inflating: validate.zarr/agents_mask/0.5/8731.0
#   inflating: validate.zarr/agents_mask/0.5/8732.0
#   inflating: validate.zarr/agents_mask/0.5/8733.0
#   inflating: validate.zarr/agents_mask/0.5/8734.0
#   inflating: validate.zarr/agents_mask/0.5/8735.0
#   inflating: validate.zarr/agents_mask/0.5/8736.0
#   inflating: validate.zarr/agents_mask/0.5/8737.0
#   inflating: validate.zarr/agents_mask/0.5/8738.0
#   inflating: validate.zarr/agents_mask/0.5/8739.0
#   inflating: validate.zarr/agents_mask/0.5/874.0
#   inflating: validate.zarr/agents_mask/0.5/8740.0
#   inflating: validate.zarr/agents_mask/0.5/8741.0
#   inflating: validate.zarr/agents_mask/0.5/8742.0
#   inflating: validate.zarr/agents_mask/0.5/8743.0
#   inflating: validate.zarr/agents_mask/0.5/8744.0
#   inflating: validate.zarr/agents_mask/0.5/8745.0
#   inflating: validate.zarr/agents_mask/0.5/8746.0
#   inflating: validate.zarr/agents_mask/0.5/8747.0
#   inflating: validate.zarr/agents_mask/0.5/8748.0
#   inflating: validate.zarr/agents_mask/0.5/8749.0
#   inflating: validate.zarr/agents_mask/0.5/875.0
#   inflating: validate.zarr/agents_mask/0.5/8750.0
#   inflating: validate.zarr/agents_mask/0.5/8751.0
#   inflating: validate.zarr/agents_mask/0.5/8752.0
#   inflating: validate.zarr/agents_mask/0.5/8753.0
#   inflating: validate.zarr/agents_mask/0.5/8754.0
#   inflating: validate.zarr/agents_mask/0.5/8755.0
#   inflating: validate.zarr/agents_mask/0.5/8756.0
#   inflating: validate.zarr/agents_mask/0.5/8757.0
#   inflating: validate.zarr/agents_mask/0.5/8758.0
#   inflating: validate.zarr/agents_mask/0.5/8759.0
#   inflating: validate.zarr/agents_mask/0.5/876.0
#   inflating: validate.zarr/agents_mask/0.5/8760.0
#   inflating: validate.zarr/agents_mask/0.5/8761.0
#   inflating: validate.zarr/agents_mask/0.5/8762.0
#   inflating: validate.zarr/agents_mask/0.5/8763.0
#   inflating: validate.zarr/agents_mask/0.5/8764.0
#   inflating: validate.zarr/agents_mask/0.5/8765.0
#   inflating: validate.zarr/agents_mask/0.5/8766.0
#   inflating: validate.zarr/agents_mask/0.5/8767.0
#   inflating: validate.zarr/agents_mask/0.5/8768.0
#   inflating: validate.zarr/agents_mask/0.5/8769.0
#   inflating: validate.zarr/agents_mask/0.5/877.0
#   inflating: validate.zarr/agents_mask/0.5/8770.0
#   inflating: validate.zarr/agents_mask/0.5/8771.0
#   inflating: validate.zarr/agents_mask/0.5/8772.0
#   inflating: validate.zarr/agents_mask/0.5/8773.0
#   inflating: validate.zarr/agents_mask/0.5/8774.0
#   inflating: validate.zarr/agents_mask/0.5/8775.0
#   inflating: validate.zarr/agents_mask/0.5/8776.0
#   inflating: validate.zarr/agents_mask/0.5/8777.0
#   inflating: validate.zarr/agents_mask/0.5/8778.0
#   inflating: validate.zarr/agents_mask/0.5/8779.0
#   inflating: validate.zarr/agents_mask/0.5/878.0
#   inflating: validate.zarr/agents_mask/0.5/8780.0
#   inflating: validate.zarr/agents_mask/0.5/8781.0
#   inflating: validate.zarr/agents_mask/0.5/8782.0
#   inflating: validate.zarr/agents_mask/0.5/8783.0
#   inflating: validate.zarr/agents_mask/0.5/8784.0
#   inflating: validate.zarr/agents_mask/0.5/8785.0
#   inflating: validate.zarr/agents_mask/0.5/8786.0
#   inflating: validate.zarr/agents_mask/0.5/8787.0
#   inflating: validate.zarr/agents_mask/0.5/8788.0
#   inflating: validate.zarr/agents_mask/0.5/8789.0
#   inflating: validate.zarr/agents_mask/0.5/879.0
#   inflating: validate.zarr/agents_mask/0.5/8790.0
#   inflating: validate.zarr/agents_mask/0.5/8791.0
#   inflating: validate.zarr/agents_mask/0.5/8792.0
#   inflating: validate.zarr/agents_mask/0.5/8793.0
#   inflating: validate.zarr/agents_mask/0.5/8794.0
#   inflating: validate.zarr/agents_mask/0.5/8795.0
#   inflating: validate.zarr/agents_mask/0.5/8796.0
#   inflating: validate.zarr/agents_mask/0.5/8797.0
#   inflating: validate.zarr/agents_mask/0.5/8798.0
#   inflating: validate.zarr/agents_mask/0.5/8799.0
#   inflating: validate.zarr/agents_mask/0.5/88.0
#   inflating: validate.zarr/agents_mask/0.5/880.0
#   inflating: validate.zarr/agents_mask/0.5/8800.0
#   inflating: validate.zarr/agents_mask/0.5/8801.0
#   inflating: validate.zarr/agents_mask/0.5/8802.0
#   inflating: validate.zarr/agents_mask/0.5/8803.0
#   inflating: validate.zarr/agents_mask/0.5/8804.0
#   inflating: validate.zarr/agents_mask/0.5/8805.0
#   inflating: validate.zarr/agents_mask/0.5/8806.0
#   inflating: validate.zarr/agents_mask/0.5/8807.0
#   inflating: validate.zarr/agents_mask/0.5/8808.0
#   inflating: validate.zarr/agents_mask/0.5/8809.0
#   inflating: validate.zarr/agents_mask/0.5/881.0
#   inflating: validate.zarr/agents_mask/0.5/8810.0
#   inflating: validate.zarr/agents_mask/0.5/8811.0
#   inflating: validate.zarr/agents_mask/0.5/8812.0
#   inflating: validate.zarr/agents_mask/0.5/8813.0
#   inflating: validate.zarr/agents_mask/0.5/8814.0
#   inflating: validate.zarr/agents_mask/0.5/8815.0
#   inflating: validate.zarr/agents_mask/0.5/8816.0
#   inflating: validate.zarr/agents_mask/0.5/8817.0
#   inflating: validate.zarr/agents_mask/0.5/8818.0
#   inflating: validate.zarr/agents_mask/0.5/8819.0
#   inflating: validate.zarr/agents_mask/0.5/882.0
#   inflating: validate.zarr/agents_mask/0.5/8820.0
#   inflating: validate.zarr/agents_mask/0.5/8821.0
#   inflating: validate.zarr/agents_mask/0.5/8822.0
#   inflating: validate.zarr/agents_mask/0.5/8823.0
#   inflating: validate.zarr/agents_mask/0.5/8824.0
#   inflating: validate.zarr/agents_mask/0.5/8825.0
#   inflating: validate.zarr/agents_mask/0.5/8826.0
#   inflating: validate.zarr/agents_mask/0.5/8827.0
#   inflating: validate.zarr/agents_mask/0.5/8828.0
#   inflating: validate.zarr/agents_mask/0.5/8829.0
#   inflating: validate.zarr/agents_mask/0.5/883.0
#   inflating: validate.zarr/agents_mask/0.5/8830.0
#   inflating: validate.zarr/agents_mask/0.5/8831.0
#   inflating: validate.zarr/agents_mask/0.5/8832.0
#   inflating: validate.zarr/agents_mask/0.5/8833.0
#   inflating: validate.zarr/agents_mask/0.5/8834.0
#   inflating: validate.zarr/agents_mask/0.5/8835.0
#   inflating: validate.zarr/agents_mask/0.5/8836.0
#   inflating: validate.zarr/agents_mask/0.5/8837.0
#   inflating: validate.zarr/agents_mask/0.5/8838.0
#   inflating: validate.zarr/agents_mask/0.5/8839.0
#   inflating: validate.zarr/agents_mask/0.5/884.0
#   inflating: validate.zarr/agents_mask/0.5/8840.0
#   inflating: validate.zarr/agents_mask/0.5/8841.0
#   inflating: validate.zarr/agents_mask/0.5/8842.0
#   inflating: validate.zarr/agents_mask/0.5/8843.0
#   inflating: validate.zarr/agents_mask/0.5/8844.0
#   inflating: validate.zarr/agents_mask/0.5/8845.0
#   inflating: validate.zarr/agents_mask/0.5/8846.0
#   inflating: validate.zarr/agents_mask/0.5/8847.0
#   inflating: validate.zarr/agents_mask/0.5/8848.0
#   inflating: validate.zarr/agents_mask/0.5/8849.0
#   inflating: validate.zarr/agents_mask/0.5/885.0
#   inflating: validate.zarr/agents_mask/0.5/8850.0
#   inflating: validate.zarr/agents_mask/0.5/8851.0
#   inflating: validate.zarr/agents_mask/0.5/8852.0
#   inflating: validate.zarr/agents_mask/0.5/8853.0
#   inflating: validate.zarr/agents_mask/0.5/8854.0
#   inflating: validate.zarr/agents_mask/0.5/8855.0
#   inflating: validate.zarr/agents_mask/0.5/8856.0
#   inflating: validate.zarr/agents_mask/0.5/8857.0
#   inflating: validate.zarr/agents_mask/0.5/8858.0
#   inflating: validate.zarr/agents_mask/0.5/8859.0
#   inflating: validate.zarr/agents_mask/0.5/886.0
#   inflating: validate.zarr/agents_mask/0.5/8860.0
#   inflating: validate.zarr/agents_mask/0.5/8861.0
#   inflating: validate.zarr/agents_mask/0.5/8862.0
#   inflating: validate.zarr/agents_mask/0.5/8863.0
#   inflating: validate.zarr/agents_mask/0.5/8864.0
#   inflating: validate.zarr/agents_mask/0.5/8865.0
#   inflating: validate.zarr/agents_mask/0.5/8866.0
#   inflating: validate.zarr/agents_mask/0.5/8867.0
#   inflating: validate.zarr/agents_mask/0.5/8868.0
#   inflating: validate.zarr/agents_mask/0.5/8869.0
#   inflating: validate.zarr/agents_mask/0.5/887.0
#   inflating: validate.zarr/agents_mask/0.5/8870.0
#   inflating: validate.zarr/agents_mask/0.5/8871.0
#   inflating: validate.zarr/agents_mask/0.5/8872.0
#   inflating: validate.zarr/agents_mask/0.5/8873.0
#   inflating: validate.zarr/agents_mask/0.5/8874.0
#   inflating: validate.zarr/agents_mask/0.5/8875.0
#   inflating: validate.zarr/agents_mask/0.5/8876.0
#   inflating: validate.zarr/agents_mask/0.5/8877.0
#   inflating: validate.zarr/agents_mask/0.5/8878.0
#   inflating: validate.zarr/agents_mask/0.5/8879.0
#   inflating: validate.zarr/agents_mask/0.5/888.0
#   inflating: validate.zarr/agents_mask/0.5/8880.0
#   inflating: validate.zarr/agents_mask/0.5/8881.0
#   inflating: validate.zarr/agents_mask/0.5/8882.0
#   inflating: validate.zarr/agents_mask/0.5/8883.0
#   inflating: validate.zarr/agents_mask/0.5/8884.0
#   inflating: validate.zarr/agents_mask/0.5/8885.0
#   inflating: validate.zarr/agents_mask/0.5/8886.0
#   inflating: validate.zarr/agents_mask/0.5/8887.0
#   inflating: validate.zarr/agents_mask/0.5/8888.0
#   inflating: validate.zarr/agents_mask/0.5/8889.0
#   inflating: validate.zarr/agents_mask/0.5/889.0
#   inflating: validate.zarr/agents_mask/0.5/8890.0
#   inflating: validate.zarr/agents_mask/0.5/8891.0
#   inflating: validate.zarr/agents_mask/0.5/8892.0
#   inflating: validate.zarr/agents_mask/0.5/8893.0
#   inflating: validate.zarr/agents_mask/0.5/8894.0
#   inflating: validate.zarr/agents_mask/0.5/8895.0
#   inflating: validate.zarr/agents_mask/0.5/8896.0
#   inflating: validate.zarr/agents_mask/0.5/8897.0
#   inflating: validate.zarr/agents_mask/0.5/8898.0
#   inflating: validate.zarr/agents_mask/0.5/8899.0
#   inflating: validate.zarr/agents_mask/0.5/89.0
#   inflating: validate.zarr/agents_mask/0.5/890.0
#   inflating: validate.zarr/agents_mask/0.5/8900.0
#   inflating: validate.zarr/agents_mask/0.5/8901.0
#   inflating: validate.zarr/agents_mask/0.5/8902.0
#   inflating: validate.zarr/agents_mask/0.5/8903.0
#   inflating: validate.zarr/agents_mask/0.5/8904.0
#   inflating: validate.zarr/agents_mask/0.5/8905.0
#   inflating: validate.zarr/agents_mask/0.5/8906.0
#   inflating: validate.zarr/agents_mask/0.5/8907.0
#   inflating: validate.zarr/agents_mask/0.5/8908.0
#   inflating: validate.zarr/agents_mask/0.5/8909.0
#   inflating: validate.zarr/agents_mask/0.5/891.0
#   inflating: validate.zarr/agents_mask/0.5/8910.0
#   inflating: validate.zarr/agents_mask/0.5/8911.0
#   inflating: validate.zarr/agents_mask/0.5/8912.0
#   inflating: validate.zarr/agents_mask/0.5/8913.0
#   inflating: validate.zarr/agents_mask/0.5/8914.0
#   inflating: validate.zarr/agents_mask/0.5/8915.0
#   inflating: validate.zarr/agents_mask/0.5/8916.0
#   inflating: validate.zarr/agents_mask/0.5/8917.0
#   inflating: validate.zarr/agents_mask/0.5/8918.0
#   inflating: validate.zarr/agents_mask/0.5/8919.0
#   inflating: validate.zarr/agents_mask/0.5/892.0
#   inflating: validate.zarr/agents_mask/0.5/8920.0
#   inflating: validate.zarr/agents_mask/0.5/8921.0
#   inflating: validate.zarr/agents_mask/0.5/8922.0
#   inflating: validate.zarr/agents_mask/0.5/8923.0
#   inflating: validate.zarr/agents_mask/0.5/8924.0
#   inflating: validate.zarr/agents_mask/0.5/8925.0
#   inflating: validate.zarr/agents_mask/0.5/8926.0
#   inflating: validate.zarr/agents_mask/0.5/8927.0
#   inflating: validate.zarr/agents_mask/0.5/8928.0
#   inflating: validate.zarr/agents_mask/0.5/8929.0
#   inflating: validate.zarr/agents_mask/0.5/893.0
#   inflating: validate.zarr/agents_mask/0.5/8930.0
#   inflating: validate.zarr/agents_mask/0.5/8931.0
#   inflating: validate.zarr/agents_mask/0.5/8932.0
#   inflating: validate.zarr/agents_mask/0.5/8933.0
#   inflating: validate.zarr/agents_mask/0.5/8934.0
#   inflating: validate.zarr/agents_mask/0.5/8935.0
#   inflating: validate.zarr/agents_mask/0.5/8936.0
#   inflating: validate.zarr/agents_mask/0.5/8937.0
#   inflating: validate.zarr/agents_mask/0.5/8938.0
#   inflating: validate.zarr/agents_mask/0.5/8939.0
#   inflating: validate.zarr/agents_mask/0.5/894.0
#   inflating: validate.zarr/agents_mask/0.5/8940.0
#   inflating: validate.zarr/agents_mask/0.5/8941.0
#   inflating: validate.zarr/agents_mask/0.5/8942.0
#   inflating: validate.zarr/agents_mask/0.5/8943.0
#   inflating: validate.zarr/agents_mask/0.5/8944.0
#   inflating: validate.zarr/agents_mask/0.5/8945.0
#   inflating: validate.zarr/agents_mask/0.5/8946.0
#   inflating: validate.zarr/agents_mask/0.5/8947.0
#   inflating: validate.zarr/agents_mask/0.5/8948.0
#   inflating: validate.zarr/agents_mask/0.5/8949.0
#   inflating: validate.zarr/agents_mask/0.5/895.0
#   inflating: validate.zarr/agents_mask/0.5/8950.0
#   inflating: validate.zarr/agents_mask/0.5/8951.0
#   inflating: validate.zarr/agents_mask/0.5/8952.0
#   inflating: validate.zarr/agents_mask/0.5/8953.0
#   inflating: validate.zarr/agents_mask/0.5/8954.0
#   inflating: validate.zarr/agents_mask/0.5/8955.0
#   inflating: validate.zarr/agents_mask/0.5/8956.0
#   inflating: validate.zarr/agents_mask/0.5/8957.0
#   inflating: validate.zarr/agents_mask/0.5/8958.0
#   inflating: validate.zarr/agents_mask/0.5/8959.0
#   inflating: validate.zarr/agents_mask/0.5/896.0
#   inflating: validate.zarr/agents_mask/0.5/8960.0
#   inflating: validate.zarr/agents_mask/0.5/8961.0
#   inflating: validate.zarr/agents_mask/0.5/8962.0
#   inflating: validate.zarr/agents_mask/0.5/8963.0
#   inflating: validate.zarr/agents_mask/0.5/8964.0
#   inflating: validate.zarr/agents_mask/0.5/8965.0
#   inflating: validate.zarr/agents_mask/0.5/8966.0
#   inflating: validate.zarr/agents_mask/0.5/8967.0
#   inflating: validate.zarr/agents_mask/0.5/8968.0
#   inflating: validate.zarr/agents_mask/0.5/8969.0
#   inflating: validate.zarr/agents_mask/0.5/897.0
#   inflating: validate.zarr/agents_mask/0.5/8970.0
#   inflating: validate.zarr/agents_mask/0.5/8971.0
#   inflating: validate.zarr/agents_mask/0.5/8972.0
#   inflating: validate.zarr/agents_mask/0.5/8973.0
#   inflating: validate.zarr/agents_mask/0.5/8974.0
#   inflating: validate.zarr/agents_mask/0.5/8975.0
#   inflating: validate.zarr/agents_mask/0.5/8976.0
#   inflating: validate.zarr/agents_mask/0.5/8977.0
#   inflating: validate.zarr/agents_mask/0.5/8978.0
#   inflating: validate.zarr/agents_mask/0.5/8979.0
#   inflating: validate.zarr/agents_mask/0.5/898.0
#   inflating: validate.zarr/agents_mask/0.5/8980.0
#   inflating: validate.zarr/agents_mask/0.5/8981.0
#   inflating: validate.zarr/agents_mask/0.5/8982.0
#   inflating: validate.zarr/agents_mask/0.5/8983.0
#   inflating: validate.zarr/agents_mask/0.5/8984.0
#   inflating: validate.zarr/agents_mask/0.5/8985.0
#   inflating: validate.zarr/agents_mask/0.5/8986.0
#   inflating: validate.zarr/agents_mask/0.5/8987.0
#   inflating: validate.zarr/agents_mask/0.5/8988.0
#   inflating: validate.zarr/agents_mask/0.5/8989.0
#   inflating: validate.zarr/agents_mask/0.5/899.0
#   inflating: validate.zarr/agents_mask/0.5/8990.0
#   inflating: validate.zarr/agents_mask/0.5/8991.0
#   inflating: validate.zarr/agents_mask/0.5/8992.0
#   inflating: validate.zarr/agents_mask/0.5/8993.0
#   inflating: validate.zarr/agents_mask/0.5/8994.0
#   inflating: validate.zarr/agents_mask/0.5/8995.0
#   inflating: validate.zarr/agents_mask/0.5/8996.0
#   inflating: validate.zarr/agents_mask/0.5/8997.0
#   inflating: validate.zarr/agents_mask/0.5/8998.0
#   inflating: validate.zarr/agents_mask/0.5/8999.0
#   inflating: validate.zarr/agents_mask/0.5/9.0
#   inflating: validate.zarr/agents_mask/0.5/90.0
#   inflating: validate.zarr/agents_mask/0.5/900.0
#   inflating: validate.zarr/agents_mask/0.5/9000.0
#   inflating: validate.zarr/agents_mask/0.5/9001.0
#   inflating: validate.zarr/agents_mask/0.5/9002.0
#   inflating: validate.zarr/agents_mask/0.5/9003.0
#   inflating: validate.zarr/agents_mask/0.5/9004.0
#   inflating: validate.zarr/agents_mask/0.5/9005.0
#   inflating: validate.zarr/agents_mask/0.5/9006.0
#   inflating: validate.zarr/agents_mask/0.5/9007.0
#   inflating: validate.zarr/agents_mask/0.5/9008.0
#   inflating: validate.zarr/agents_mask/0.5/9009.0
#   inflating: validate.zarr/agents_mask/0.5/901.0
#   inflating: validate.zarr/agents_mask/0.5/9010.0
#   inflating: validate.zarr/agents_mask/0.5/9011.0
#   inflating: validate.zarr/agents_mask/0.5/9012.0
#   inflating: validate.zarr/agents_mask/0.5/9013.0
#   inflating: validate.zarr/agents_mask/0.5/9014.0
#   inflating: validate.zarr/agents_mask/0.5/9015.0
#   inflating: validate.zarr/agents_mask/0.5/9016.0
#   inflating: validate.zarr/agents_mask/0.5/9017.0
#   inflating: validate.zarr/agents_mask/0.5/9018.0
#   inflating: validate.zarr/agents_mask/0.5/9019.0
#   inflating: validate.zarr/agents_mask/0.5/902.0
#   inflating: validate.zarr/agents_mask/0.5/9020.0
#   inflating: validate.zarr/agents_mask/0.5/9021.0
#   inflating: validate.zarr/agents_mask/0.5/9022.0
#   inflating: validate.zarr/agents_mask/0.5/9023.0
#   inflating: validate.zarr/agents_mask/0.5/9024.0
#   inflating: validate.zarr/agents_mask/0.5/9025.0
#   inflating: validate.zarr/agents_mask/0.5/9026.0
#   inflating: validate.zarr/agents_mask/0.5/9027.0
#   inflating: validate.zarr/agents_mask/0.5/9028.0
#   inflating: validate.zarr/agents_mask/0.5/9029.0
#   inflating: validate.zarr/agents_mask/0.5/903.0
#   inflating: validate.zarr/agents_mask/0.5/9030.0
#   inflating: validate.zarr/agents_mask/0.5/9031.0
#   inflating: validate.zarr/agents_mask/0.5/9032.0
#   inflating: validate.zarr/agents_mask/0.5/9033.0
#   inflating: validate.zarr/agents_mask/0.5/9034.0
#   inflating: validate.zarr/agents_mask/0.5/9035.0
#   inflating: validate.zarr/agents_mask/0.5/9036.0
#   inflating: validate.zarr/agents_mask/0.5/9037.0
#   inflating: validate.zarr/agents_mask/0.5/9038.0
#   inflating: validate.zarr/agents_mask/0.5/9039.0
#   inflating: validate.zarr/agents_mask/0.5/904.0
#   inflating: validate.zarr/agents_mask/0.5/9040.0
#   inflating: validate.zarr/agents_mask/0.5/9041.0
#   inflating: validate.zarr/agents_mask/0.5/9042.0
#   inflating: validate.zarr/agents_mask/0.5/9043.0
#   inflating: validate.zarr/agents_mask/0.5/9044.0
#   inflating: validate.zarr/agents_mask/0.5/9045.0
#   inflating: validate.zarr/agents_mask/0.5/9046.0
#   inflating: validate.zarr/agents_mask/0.5/9047.0
#   inflating: validate.zarr/agents_mask/0.5/9048.0
#   inflating: validate.zarr/agents_mask/0.5/9049.0
#   inflating: validate.zarr/agents_mask/0.5/905.0
#   inflating: validate.zarr/agents_mask/0.5/9050.0
#   inflating: validate.zarr/agents_mask/0.5/9051.0
#   inflating: validate.zarr/agents_mask/0.5/9052.0
#   inflating: validate.zarr/agents_mask/0.5/9053.0
#   inflating: validate.zarr/agents_mask/0.5/9054.0
#   inflating: validate.zarr/agents_mask/0.5/9055.0
#   inflating: validate.zarr/agents_mask/0.5/9056.0
#   inflating: validate.zarr/agents_mask/0.5/9057.0
#   inflating: validate.zarr/agents_mask/0.5/9058.0
#   inflating: validate.zarr/agents_mask/0.5/9059.0
#   inflating: validate.zarr/agents_mask/0.5/906.0
#   inflating: validate.zarr/agents_mask/0.5/9060.0
#   inflating: validate.zarr/agents_mask/0.5/9061.0
#   inflating: validate.zarr/agents_mask/0.5/9062.0
#   inflating: validate.zarr/agents_mask/0.5/9063.0
#   inflating: validate.zarr/agents_mask/0.5/9064.0
#   inflating: validate.zarr/agents_mask/0.5/9065.0
#   inflating: validate.zarr/agents_mask/0.5/9066.0
#   inflating: validate.zarr/agents_mask/0.5/9067.0
#   inflating: validate.zarr/agents_mask/0.5/9068.0
#   inflating: validate.zarr/agents_mask/0.5/9069.0
#   inflating: validate.zarr/agents_mask/0.5/907.0
#   inflating: validate.zarr/agents_mask/0.5/9070.0
#   inflating: validate.zarr/agents_mask/0.5/9071.0
#   inflating: validate.zarr/agents_mask/0.5/9072.0
#   inflating: validate.zarr/agents_mask/0.5/9073.0
#   inflating: validate.zarr/agents_mask/0.5/9074.0
#   inflating: validate.zarr/agents_mask/0.5/9075.0
#   inflating: validate.zarr/agents_mask/0.5/9076.0
#   inflating: validate.zarr/agents_mask/0.5/9077.0
#   inflating: validate.zarr/agents_mask/0.5/9078.0
#   inflating: validate.zarr/agents_mask/0.5/9079.0
#   inflating: validate.zarr/agents_mask/0.5/908.0
#   inflating: validate.zarr/agents_mask/0.5/9080.0
#   inflating: validate.zarr/agents_mask/0.5/9081.0
#   inflating: validate.zarr/agents_mask/0.5/9082.0
#   inflating: validate.zarr/agents_mask/0.5/9083.0
#   inflating: validate.zarr/agents_mask/0.5/9084.0
#   inflating: validate.zarr/agents_mask/0.5/9085.0
#   inflating: validate.zarr/agents_mask/0.5/9086.0
#   inflating: validate.zarr/agents_mask/0.5/9087.0
#   inflating: validate.zarr/agents_mask/0.5/9088.0
#   inflating: validate.zarr/agents_mask/0.5/9089.0
#   inflating: validate.zarr/agents_mask/0.5/909.0
#   inflating: validate.zarr/agents_mask/0.5/9090.0
#   inflating: validate.zarr/agents_mask/0.5/9091.0
#   inflating: validate.zarr/agents_mask/0.5/9092.0
#   inflating: validate.zarr/agents_mask/0.5/9093.0
#   inflating: validate.zarr/agents_mask/0.5/9094.0
#   inflating: validate.zarr/agents_mask/0.5/9095.0
#   inflating: validate.zarr/agents_mask/0.5/9096.0
#   inflating: validate.zarr/agents_mask/0.5/9097.0
#   inflating: validate.zarr/agents_mask/0.5/9098.0
#   inflating: validate.zarr/agents_mask/0.5/9099.0
#   inflating: validate.zarr/agents_mask/0.5/91.0
#   inflating: validate.zarr/agents_mask/0.5/910.0
#   inflating: validate.zarr/agents_mask/0.5/9100.0
#   inflating: validate.zarr/agents_mask/0.5/9101.0
#   inflating: validate.zarr/agents_mask/0.5/9102.0
#   inflating: validate.zarr/agents_mask/0.5/9103.0
#   inflating: validate.zarr/agents_mask/0.5/9104.0
#   inflating: validate.zarr/agents_mask/0.5/9105.0
#   inflating: validate.zarr/agents_mask/0.5/9106.0
#   inflating: validate.zarr/agents_mask/0.5/9107.0
#   inflating: validate.zarr/agents_mask/0.5/9108.0
#   inflating: validate.zarr/agents_mask/0.5/9109.0
#   inflating: validate.zarr/agents_mask/0.5/911.0
#   inflating: validate.zarr/agents_mask/0.5/9110.0
#   inflating: validate.zarr/agents_mask/0.5/9111.0
#   inflating: validate.zarr/agents_mask/0.5/9112.0
#   inflating: validate.zarr/agents_mask/0.5/9113.0
#   inflating: validate.zarr/agents_mask/0.5/9114.0
#   inflating: validate.zarr/agents_mask/0.5/9115.0
#   inflating: validate.zarr/agents_mask/0.5/9116.0
#   inflating: validate.zarr/agents_mask/0.5/9117.0
#   inflating: validate.zarr/agents_mask/0.5/9118.0
#   inflating: validate.zarr/agents_mask/0.5/9119.0
#   inflating: validate.zarr/agents_mask/0.5/912.0
#   inflating: validate.zarr/agents_mask/0.5/9120.0
#   inflating: validate.zarr/agents_mask/0.5/9121.0
#   inflating: validate.zarr/agents_mask/0.5/9122.0
#   inflating: validate.zarr/agents_mask/0.5/9123.0
#   inflating: validate.zarr/agents_mask/0.5/9124.0
#   inflating: validate.zarr/agents_mask/0.5/9125.0
#   inflating: validate.zarr/agents_mask/0.5/9126.0
#   inflating: validate.zarr/agents_mask/0.5/9127.0
#   inflating: validate.zarr/agents_mask/0.5/9128.0
#   inflating: validate.zarr/agents_mask/0.5/9129.0
#   inflating: validate.zarr/agents_mask/0.5/913.0
#   inflating: validate.zarr/agents_mask/0.5/9130.0
#   inflating: validate.zarr/agents_mask/0.5/9131.0
#   inflating: validate.zarr/agents_mask/0.5/9132.0
#   inflating: validate.zarr/agents_mask/0.5/9133.0
#   inflating: validate.zarr/agents_mask/0.5/9134.0
#   inflating: validate.zarr/agents_mask/0.5/9135.0
#   inflating: validate.zarr/agents_mask/0.5/9136.0
#   inflating: validate.zarr/agents_mask/0.5/9137.0
#   inflating: validate.zarr/agents_mask/0.5/9138.0
#   inflating: validate.zarr/agents_mask/0.5/9139.0
#   inflating: validate.zarr/agents_mask/0.5/914.0
#   inflating: validate.zarr/agents_mask/0.5/9140.0
#   inflating: validate.zarr/agents_mask/0.5/9141.0
#   inflating: validate.zarr/agents_mask/0.5/9142.0
#   inflating: validate.zarr/agents_mask/0.5/9143.0
#   inflating: validate.zarr/agents_mask/0.5/9144.0
#   inflating: validate.zarr/agents_mask/0.5/9145.0
#   inflating: validate.zarr/agents_mask/0.5/9146.0
#   inflating: validate.zarr/agents_mask/0.5/9147.0
#   inflating: validate.zarr/agents_mask/0.5/9148.0
#   inflating: validate.zarr/agents_mask/0.5/9149.0
#   inflating: validate.zarr/agents_mask/0.5/915.0
#   inflating: validate.zarr/agents_mask/0.5/9150.0
#   inflating: validate.zarr/agents_mask/0.5/9151.0
#   inflating: validate.zarr/agents_mask/0.5/9152.0
#   inflating: validate.zarr/agents_mask/0.5/9153.0
#   inflating: validate.zarr/agents_mask/0.5/9154.0
#   inflating: validate.zarr/agents_mask/0.5/9155.0
#   inflating: validate.zarr/agents_mask/0.5/9156.0
#   inflating: validate.zarr/agents_mask/0.5/9157.0
#   inflating: validate.zarr/agents_mask/0.5/9158.0
#   inflating: validate.zarr/agents_mask/0.5/9159.0
#   inflating: validate.zarr/agents_mask/0.5/916.0
#   inflating: validate.zarr/agents_mask/0.5/9160.0
#   inflating: validate.zarr/agents_mask/0.5/9161.0
#   inflating: validate.zarr/agents_mask/0.5/9162.0
#   inflating: validate.zarr/agents_mask/0.5/9163.0
#   inflating: validate.zarr/agents_mask/0.5/9164.0
#   inflating: validate.zarr/agents_mask/0.5/9165.0
#   inflating: validate.zarr/agents_mask/0.5/9166.0
#   inflating: validate.zarr/agents_mask/0.5/9167.0
#   inflating: validate.zarr/agents_mask/0.5/9168.0
#   inflating: validate.zarr/agents_mask/0.5/9169.0
#   inflating: validate.zarr/agents_mask/0.5/917.0
#   inflating: validate.zarr/agents_mask/0.5/9170.0
#   inflating: validate.zarr/agents_mask/0.5/9171.0
#   inflating: validate.zarr/agents_mask/0.5/9172.0
#   inflating: validate.zarr/agents_mask/0.5/9173.0
#   inflating: validate.zarr/agents_mask/0.5/9174.0
#   inflating: validate.zarr/agents_mask/0.5/9175.0
#   inflating: validate.zarr/agents_mask/0.5/9176.0
#   inflating: validate.zarr/agents_mask/0.5/9177.0
#   inflating: validate.zarr/agents_mask/0.5/9178.0
#   inflating: validate.zarr/agents_mask/0.5/9179.0
#   inflating: validate.zarr/agents_mask/0.5/918.0
#   inflating: validate.zarr/agents_mask/0.5/9180.0
#   inflating: validate.zarr/agents_mask/0.5/9181.0
#   inflating: validate.zarr/agents_mask/0.5/9182.0
#   inflating: validate.zarr/agents_mask/0.5/9183.0
#   inflating: validate.zarr/agents_mask/0.5/9184.0
#   inflating: validate.zarr/agents_mask/0.5/9185.0
#   inflating: validate.zarr/agents_mask/0.5/9186.0
#   inflating: validate.zarr/agents_mask/0.5/9187.0
#   inflating: validate.zarr/agents_mask/0.5/9188.0
#   inflating: validate.zarr/agents_mask/0.5/9189.0
#   inflating: validate.zarr/agents_mask/0.5/919.0
#   inflating: validate.zarr/agents_mask/0.5/9190.0
#   inflating: validate.zarr/agents_mask/0.5/9191.0
#   inflating: validate.zarr/agents_mask/0.5/9192.0
#   inflating: validate.zarr/agents_mask/0.5/9193.0
#   inflating: validate.zarr/agents_mask/0.5/9194.0
#   inflating: validate.zarr/agents_mask/0.5/9195.0
#   inflating: validate.zarr/agents_mask/0.5/9196.0
#   inflating: validate.zarr/agents_mask/0.5/9197.0
#   inflating: validate.zarr/agents_mask/0.5/9198.0
#   inflating: validate.zarr/agents_mask/0.5/9199.0
#   inflating: validate.zarr/agents_mask/0.5/92.0
#   inflating: validate.zarr/agents_mask/0.5/920.0
#   inflating: validate.zarr/agents_mask/0.5/9200.0
#   inflating: validate.zarr/agents_mask/0.5/9201.0
#   inflating: validate.zarr/agents_mask/0.5/9202.0
#   inflating: validate.zarr/agents_mask/0.5/9203.0
#   inflating: validate.zarr/agents_mask/0.5/9204.0
#   inflating: validate.zarr/agents_mask/0.5/9205.0
#   inflating: validate.zarr/agents_mask/0.5/9206.0
#   inflating: validate.zarr/agents_mask/0.5/9207.0
#   inflating: validate.zarr/agents_mask/0.5/9208.0
#   inflating: validate.zarr/agents_mask/0.5/9209.0
#   inflating: validate.zarr/agents_mask/0.5/921.0
#   inflating: validate.zarr/agents_mask/0.5/9210.0
#   inflating: validate.zarr/agents_mask/0.5/9211.0
#   inflating: validate.zarr/agents_mask/0.5/9212.0
#   inflating: validate.zarr/agents_mask/0.5/9213.0
#   inflating: validate.zarr/agents_mask/0.5/9214.0
#   inflating: validate.zarr/agents_mask/0.5/9215.0
#   inflating: validate.zarr/agents_mask/0.5/9216.0
#   inflating: validate.zarr/agents_mask/0.5/9217.0
#   inflating: validate.zarr/agents_mask/0.5/9218.0
#   inflating: validate.zarr/agents_mask/0.5/9219.0
#   inflating: validate.zarr/agents_mask/0.5/922.0
#   inflating: validate.zarr/agents_mask/0.5/9220.0
#   inflating: validate.zarr/agents_mask/0.5/9221.0
#   inflating: validate.zarr/agents_mask/0.5/9222.0
#   inflating: validate.zarr/agents_mask/0.5/9223.0
#   inflating: validate.zarr/agents_mask/0.5/9224.0
#   inflating: validate.zarr/agents_mask/0.5/9225.0
#   inflating: validate.zarr/agents_mask/0.5/9226.0
#   inflating: validate.zarr/agents_mask/0.5/9227.0
#   inflating: validate.zarr/agents_mask/0.5/9228.0
#   inflating: validate.zarr/agents_mask/0.5/9229.0
#   inflating: validate.zarr/agents_mask/0.5/923.0
#   inflating: validate.zarr/agents_mask/0.5/9230.0
#   inflating: validate.zarr/agents_mask/0.5/9231.0
#   inflating: validate.zarr/agents_mask/0.5/9232.0
#   inflating: validate.zarr/agents_mask/0.5/9233.0
#   inflating: validate.zarr/agents_mask/0.5/9234.0
#   inflating: validate.zarr/agents_mask/0.5/9235.0
#   inflating: validate.zarr/agents_mask/0.5/9236.0
#   inflating: validate.zarr/agents_mask/0.5/9237.0
#   inflating: validate.zarr/agents_mask/0.5/9238.0
#   inflating: validate.zarr/agents_mask/0.5/9239.0
#   inflating: validate.zarr/agents_mask/0.5/924.0
#   inflating: validate.zarr/agents_mask/0.5/9240.0
#   inflating: validate.zarr/agents_mask/0.5/9241.0
#   inflating: validate.zarr/agents_mask/0.5/9242.0
#   inflating: validate.zarr/agents_mask/0.5/9243.0
#   inflating: validate.zarr/agents_mask/0.5/9244.0
#   inflating: validate.zarr/agents_mask/0.5/9245.0
#   inflating: validate.zarr/agents_mask/0.5/9246.0
#   inflating: validate.zarr/agents_mask/0.5/9247.0
#   inflating: validate.zarr/agents_mask/0.5/9248.0
#   inflating: validate.zarr/agents_mask/0.5/9249.0
#   inflating: validate.zarr/agents_mask/0.5/925.0
#   inflating: validate.zarr/agents_mask/0.5/9250.0
#   inflating: validate.zarr/agents_mask/0.5/9251.0
#   inflating: validate.zarr/agents_mask/0.5/9252.0
#   inflating: validate.zarr/agents_mask/0.5/9253.0
#   inflating: validate.zarr/agents_mask/0.5/9254.0
#   inflating: validate.zarr/agents_mask/0.5/9255.0
#   inflating: validate.zarr/agents_mask/0.5/9256.0
#   inflating: validate.zarr/agents_mask/0.5/9257.0
#   inflating: validate.zarr/agents_mask/0.5/9258.0
#   inflating: validate.zarr/agents_mask/0.5/9259.0
#   inflating: validate.zarr/agents_mask/0.5/926.0
#   inflating: validate.zarr/agents_mask/0.5/9260.0
#   inflating: validate.zarr/agents_mask/0.5/9261.0
#   inflating: validate.zarr/agents_mask/0.5/9262.0
#   inflating: validate.zarr/agents_mask/0.5/9263.0
#   inflating: validate.zarr/agents_mask/0.5/9264.0
#   inflating: validate.zarr/agents_mask/0.5/9265.0
#   inflating: validate.zarr/agents_mask/0.5/9266.0
#   inflating: validate.zarr/agents_mask/0.5/9267.0
#   inflating: validate.zarr/agents_mask/0.5/9268.0
#   inflating: validate.zarr/agents_mask/0.5/9269.0
#   inflating: validate.zarr/agents_mask/0.5/927.0
#   inflating: validate.zarr/agents_mask/0.5/9270.0
#   inflating: validate.zarr/agents_mask/0.5/9271.0
#   inflating: validate.zarr/agents_mask/0.5/9272.0
#   inflating: validate.zarr/agents_mask/0.5/9273.0
#   inflating: validate.zarr/agents_mask/0.5/9274.0
#   inflating: validate.zarr/agents_mask/0.5/9275.0
#   inflating: validate.zarr/agents_mask/0.5/9276.0
#   inflating: validate.zarr/agents_mask/0.5/9277.0
#   inflating: validate.zarr/agents_mask/0.5/9278.0
#   inflating: validate.zarr/agents_mask/0.5/9279.0
#   inflating: validate.zarr/agents_mask/0.5/928.0
#   inflating: validate.zarr/agents_mask/0.5/9280.0
#   inflating: validate.zarr/agents_mask/0.5/9281.0
#   inflating: validate.zarr/agents_mask/0.5/9282.0
#   inflating: validate.zarr/agents_mask/0.5/9283.0
#   inflating: validate.zarr/agents_mask/0.5/9284.0
#   inflating: validate.zarr/agents_mask/0.5/9285.0
#   inflating: validate.zarr/agents_mask/0.5/9286.0
#   inflating: validate.zarr/agents_mask/0.5/9287.0
#   inflating: validate.zarr/agents_mask/0.5/9288.0
#   inflating: validate.zarr/agents_mask/0.5/9289.0
#   inflating: validate.zarr/agents_mask/0.5/929.0
#   inflating: validate.zarr/agents_mask/0.5/9290.0
#   inflating: validate.zarr/agents_mask/0.5/9291.0
#   inflating: validate.zarr/agents_mask/0.5/9292.0
#   inflating: validate.zarr/agents_mask/0.5/9293.0
#   inflating: validate.zarr/agents_mask/0.5/9294.0
#   inflating: validate.zarr/agents_mask/0.5/9295.0
#   inflating: validate.zarr/agents_mask/0.5/9296.0
#   inflating: validate.zarr/agents_mask/0.5/9297.0
#   inflating: validate.zarr/agents_mask/0.5/9298.0
#   inflating: validate.zarr/agents_mask/0.5/9299.0
#   inflating: validate.zarr/agents_mask/0.5/93.0
#   inflating: validate.zarr/agents_mask/0.5/930.0
#   inflating: validate.zarr/agents_mask/0.5/9300.0
#   inflating: validate.zarr/agents_mask/0.5/9301.0
#   inflating: validate.zarr/agents_mask/0.5/9302.0
#   inflating: validate.zarr/agents_mask/0.5/9303.0
#   inflating: validate.zarr/agents_mask/0.5/9304.0
#   inflating: validate.zarr/agents_mask/0.5/9305.0
#   inflating: validate.zarr/agents_mask/0.5/9306.0
#   inflating: validate.zarr/agents_mask/0.5/9307.0
#   inflating: validate.zarr/agents_mask/0.5/9308.0
#   inflating: validate.zarr/agents_mask/0.5/9309.0
#   inflating: validate.zarr/agents_mask/0.5/931.0
#   inflating: validate.zarr/agents_mask/0.5/9310.0
#   inflating: validate.zarr/agents_mask/0.5/9311.0
#   inflating: validate.zarr/agents_mask/0.5/9312.0
#   inflating: validate.zarr/agents_mask/0.5/9313.0
#   inflating: validate.zarr/agents_mask/0.5/9314.0
#   inflating: validate.zarr/agents_mask/0.5/9315.0
#   inflating: validate.zarr/agents_mask/0.5/9316.0
#   inflating: validate.zarr/agents_mask/0.5/9317.0
#   inflating: validate.zarr/agents_mask/0.5/9318.0
#   inflating: validate.zarr/agents_mask/0.5/9319.0
#   inflating: validate.zarr/agents_mask/0.5/932.0
#   inflating: validate.zarr/agents_mask/0.5/9320.0
#   inflating: validate.zarr/agents_mask/0.5/9321.0
#   inflating: validate.zarr/agents_mask/0.5/9322.0
#   inflating: validate.zarr/agents_mask/0.5/9323.0
#   inflating: validate.zarr/agents_mask/0.5/9324.0
#   inflating: validate.zarr/agents_mask/0.5/9325.0
#   inflating: validate.zarr/agents_mask/0.5/9326.0
#   inflating: validate.zarr/agents_mask/0.5/9327.0
#   inflating: validate.zarr/agents_mask/0.5/9328.0
#   inflating: validate.zarr/agents_mask/0.5/9329.0
#   inflating: validate.zarr/agents_mask/0.5/933.0
#   inflating: validate.zarr/agents_mask/0.5/9330.0
#   inflating: validate.zarr/agents_mask/0.5/9331.0
#   inflating: validate.zarr/agents_mask/0.5/9332.0
#   inflating: validate.zarr/agents_mask/0.5/9333.0
# ...
#   inflating: validate.zarr/traffic_light_faces/727
#   inflating: validate.zarr/traffic_light_faces/728
#   inflating: validate.zarr/traffic_light_faces/729
#   inflating: validate.zarr/traffic_light_faces/73
#   inflating: validate.zarr/traffic_light_faces/730
#   inflating: validate.zarr/traffic_light_faces/731
#   inflating: validate.zarr/traffic_light_faces/732
#   inflating: validate.zarr/traffic_light_faces/733
#   inflating: validate.zarr/traffic_light_faces/734
#   inflating: validate.zarr/traffic_light_faces/735
#   inflating: validate.zarr/traffic_light_faces/736
#   inflating: validate.zarr/traffic_light_faces/737
#   inflating: validate.zarr/traffic_light_faces/738
#   inflating: validate.zarr/traffic_light_faces/739
#   inflating: validate.zarr/traffic_light_faces/74
#   inflating: validate.zarr/traffic_light_faces/740
#   inflating: validate.zarr/traffic_light_faces/741
#   inflating: validate.zarr/traffic_light_faces/742
#   inflating: validate.zarr/traffic_light_faces/743
#   inflating: validate.zarr/traffic_light_faces/744
#   inflating: validate.zarr/traffic_light_faces/745
#   inflating: validate.zarr/traffic_light_faces/746
#   inflating: validate.zarr/traffic_light_faces/747
#   inflating: validate.zarr/traffic_light_faces/748
#   inflating: validate.zarr/traffic_light_faces/749
#   inflating: validate.zarr/traffic_light_faces/75
#   inflating: validate.zarr/traffic_light_faces/750
#   inflating: validate.zarr/traffic_light_faces/751
#   inflating: validate.zarr/traffic_light_faces/752
#   inflating: validate.zarr/traffic_light_faces/753
#   inflating: validate.zarr/traffic_light_faces/754
#   inflating: validate.zarr/traffic_light_faces/755
#   inflating: validate.zarr/traffic_light_faces/756
#   inflating: validate.zarr/traffic_light_faces/757
#   inflating: validate.zarr/traffic_light_faces/758
#   inflating: validate.zarr/traffic_light_faces/759
#   inflating: validate.zarr/traffic_light_faces/76
#   inflating: validate.zarr/traffic_light_faces/760
#   inflating: validate.zarr/traffic_light_faces/761
#   inflating: validate.zarr/traffic_light_faces/762
#   inflating: validate.zarr/traffic_light_faces/763
#   inflating: validate.zarr/traffic_light_faces/764
#   inflating: validate.zarr/traffic_light_faces/765
#   inflating: validate.zarr/traffic_light_faces/766
#   inflating: validate.zarr/traffic_light_faces/767
#   inflating: validate.zarr/traffic_light_faces/768
#   inflating: validate.zarr/traffic_light_faces/769
#   inflating: validate.zarr/traffic_light_faces/77
#   inflating: validate.zarr/traffic_light_faces/770
#   inflating: validate.zarr/traffic_light_faces/771
#   inflating: validate.zarr/traffic_light_faces/772
#   inflating: validate.zarr/traffic_light_faces/773
#   inflating: validate.zarr/traffic_light_faces/774
#   inflating: validate.zarr/traffic_light_faces/775
#   inflating: validate.zarr/traffic_light_faces/776
#   inflating: validate.zarr/traffic_light_faces/777
#   inflating: validate.zarr/traffic_light_faces/778
#   inflating: validate.zarr/traffic_light_faces/779
#   inflating: validate.zarr/traffic_light_faces/78
#   inflating: validate.zarr/traffic_light_faces/780
#   inflating: validate.zarr/traffic_light_faces/781
#   inflating: validate.zarr/traffic_light_faces/782
#   inflating: validate.zarr/traffic_light_faces/783
#   inflating: validate.zarr/traffic_light_faces/784
#   inflating: validate.zarr/traffic_light_faces/785
#   inflating: validate.zarr/traffic_light_faces/786
#   inflating: validate.zarr/traffic_light_faces/787
#   inflating: validate.zarr/traffic_light_faces/788
#   inflating: validate.zarr/traffic_light_faces/789
#   inflating: validate.zarr/traffic_light_faces/79
#   inflating: validate.zarr/traffic_light_faces/790
#   inflating: validate.zarr/traffic_light_faces/791
#   inflating: validate.zarr/traffic_light_faces/792
#   inflating: validate.zarr/traffic_light_faces/793
#   inflating: validate.zarr/traffic_light_faces/794
#   inflating: validate.zarr/traffic_light_faces/795
#   inflating: validate.zarr/traffic_light_faces/796
#   inflating: validate.zarr/traffic_light_faces/797
#   inflating: validate.zarr/traffic_light_faces/798
#   inflating: validate.zarr/traffic_light_faces/799
#   inflating: validate.zarr/traffic_light_faces/8
#   inflating: validate.zarr/traffic_light_faces/80
#   inflating: validate.zarr/traffic_light_faces/800
#   inflating: validate.zarr/traffic_light_faces/801
#   inflating: validate.zarr/traffic_light_faces/802
#   inflating: validate.zarr/traffic_light_faces/803
#   inflating: validate.zarr/traffic_light_faces/804
#   inflating: validate.zarr/traffic_light_faces/805
#   inflating: validate.zarr/traffic_light_faces/806
#   inflating: validate.zarr/traffic_light_faces/807
#   inflating: validate.zarr/traffic_light_faces/808
#   inflating: validate.zarr/traffic_light_faces/809
#   inflating: validate.zarr/traffic_light_faces/81
#   inflating: validate.zarr/traffic_light_faces/810
#   inflating: validate.zarr/traffic_light_faces/811
#   inflating: validate.zarr/traffic_light_faces/812
#   inflating: validate.zarr/traffic_light_faces/813
#   inflating: validate.zarr/traffic_light_faces/814
#   inflating: validate.zarr/traffic_light_faces/815
#   inflating: validate.zarr/traffic_light_faces/816
#   inflating: validate.zarr/traffic_light_faces/817
#   inflating: validate.zarr/traffic_light_faces/818
#   inflating: validate.zarr/traffic_light_faces/819
#   inflating: validate.zarr/traffic_light_faces/82
#   inflating: validate.zarr/traffic_light_faces/820
#   inflating: validate.zarr/traffic_light_faces/821
#   inflating: validate.zarr/traffic_light_faces/822
#   inflating: validate.zarr/traffic_light_faces/823
#   inflating: validate.zarr/traffic_light_faces/824
#   inflating: validate.zarr/traffic_light_faces/825
#   inflating: validate.zarr/traffic_light_faces/826
#   inflating: validate.zarr/traffic_light_faces/827
#   inflating: validate.zarr/traffic_light_faces/828
#   inflating: validate.zarr/traffic_light_faces/829
#   inflating: validate.zarr/traffic_light_faces/83
#   inflating: validate.zarr/traffic_light_faces/830
#   inflating: validate.zarr/traffic_light_faces/831
#   inflating: validate.zarr/traffic_light_faces/832
#   inflating: validate.zarr/traffic_light_faces/833
#   inflating: validate.zarr/traffic_light_faces/834
#   inflating: validate.zarr/traffic_light_faces/835
#   inflating: validate.zarr/traffic_light_faces/836
#   inflating: validate.zarr/traffic_light_faces/837
#   inflating: validate.zarr/traffic_light_faces/838
#   inflating: validate.zarr/traffic_light_faces/839
#   inflating: validate.zarr/traffic_light_faces/84
#   inflating: validate.zarr/traffic_light_faces/840
#   inflating: validate.zarr/traffic_light_faces/841
#   inflating: validate.zarr/traffic_light_faces/842
#   inflating: validate.zarr/traffic_light_faces/843
#   inflating: validate.zarr/traffic_light_faces/844
#   inflating: validate.zarr/traffic_light_faces/845
#   inflating: validate.zarr/traffic_light_faces/846
#   inflating: validate.zarr/traffic_light_faces/847
#   inflating: validate.zarr/traffic_light_faces/848
#   inflating: validate.zarr/traffic_light_faces/849
#   inflating: validate.zarr/traffic_light_faces/85
#   inflating: validate.zarr/traffic_light_faces/850
#   inflating: validate.zarr/traffic_light_faces/851
#   inflating: validate.zarr/traffic_light_faces/852
#   inflating: validate.zarr/traffic_light_faces/853
#   inflating: validate.zarr/traffic_light_faces/854
#   inflating: validate.zarr/traffic_light_faces/855
#   inflating: validate.zarr/traffic_light_faces/856
#   inflating: validate.zarr/traffic_light_faces/857
#   inflating: validate.zarr/traffic_light_faces/858
#   inflating: validate.zarr/traffic_light_faces/859
#   inflating: validate.zarr/traffic_light_faces/86
#   inflating: validate.zarr/traffic_light_faces/860
#   inflating: validate.zarr/traffic_light_faces/861
#   inflating: validate.zarr/traffic_light_faces/862
#   inflating: validate.zarr/traffic_light_faces/863
#   inflating: validate.zarr/traffic_light_faces/864
#   inflating: validate.zarr/traffic_light_faces/865
#   inflating: validate.zarr/traffic_light_faces/866
#   inflating: validate.zarr/traffic_light_faces/867
#   inflating: validate.zarr/traffic_light_faces/868
#   inflating: validate.zarr/traffic_light_faces/869
#   inflating: validate.zarr/traffic_light_faces/87
#   inflating: validate.zarr/traffic_light_faces/870
#   inflating: validate.zarr/traffic_light_faces/871
#   inflating: validate.zarr/traffic_light_faces/872
#   inflating: validate.zarr/traffic_light_faces/873
#   inflating: validate.zarr/traffic_light_faces/874
#   inflating: validate.zarr/traffic_light_faces/875
#   inflating: validate.zarr/traffic_light_faces/876
#   inflating: validate.zarr/traffic_light_faces/877
#   inflating: validate.zarr/traffic_light_faces/878
#   inflating: validate.zarr/traffic_light_faces/879
#   inflating: validate.zarr/traffic_light_faces/88
#   inflating: validate.zarr/traffic_light_faces/880
#   inflating: validate.zarr/traffic_light_faces/881
#   inflating: validate.zarr/traffic_light_faces/882
#   inflating: validate.zarr/traffic_light_faces/883
#   inflating: validate.zarr/traffic_light_faces/884
#   inflating: validate.zarr/traffic_light_faces/885
#   inflating: validate.zarr/traffic_light_faces/886
#   inflating: validate.zarr/traffic_light_faces/887
#   inflating: validate.zarr/traffic_light_faces/888
#   inflating: validate.zarr/traffic_light_faces/889
#   inflating: validate.zarr/traffic_light_faces/89
#   inflating: validate.zarr/traffic_light_faces/890
#   inflating: validate.zarr/traffic_light_faces/891
#   inflating: validate.zarr/traffic_light_faces/892
#   inflating: validate.zarr/traffic_light_faces/893
#   inflating: validate.zarr/traffic_light_faces/894
#   inflating: validate.zarr/traffic_light_faces/895
#   inflating: validate.zarr/traffic_light_faces/896
#   inflating: validate.zarr/traffic_light_faces/897
#   inflating: validate.zarr/traffic_light_faces/898
#   inflating: validate.zarr/traffic_light_faces/899
#   inflating: validate.zarr/traffic_light_faces/9
#   inflating: validate.zarr/traffic_light_faces/90
#   inflating: validate.zarr/traffic_light_faces/900
#   inflating: validate.zarr/traffic_light_faces/901
#   inflating: validate.zarr/traffic_light_faces/902
#   inflating: validate.zarr/traffic_light_faces/903
#   inflating: validate.zarr/traffic_light_faces/904
#   inflating: validate.zarr/traffic_light_faces/905
#   inflating: validate.zarr/traffic_light_faces/906
#   inflating: validate.zarr/traffic_light_faces/907
#   inflating: validate.zarr/traffic_light_faces/908
#   inflating: validate.zarr/traffic_light_faces/909
#   inflating: validate.zarr/traffic_light_faces/91
#   inflating: validate.zarr/traffic_light_faces/910
#   inflating: validate.zarr/traffic_light_faces/911
#   inflating: validate.zarr/traffic_light_faces/912
#   inflating: validate.zarr/traffic_light_faces/913
#   inflating: validate.zarr/traffic_light_faces/914
#   inflating: validate.zarr/traffic_light_faces/915
#   inflating: validate.zarr/traffic_light_faces/916
#   inflating: validate.zarr/traffic_light_faces/917
#   inflating: validate.zarr/traffic_light_faces/918
#   inflating: validate.zarr/traffic_light_faces/919
#   inflating: validate.zarr/traffic_light_faces/92
#   inflating: validate.zarr/traffic_light_faces/920
#   inflating: validate.zarr/traffic_light_faces/921
#   inflating: validate.zarr/traffic_light_faces/922
#   inflating: validate.zarr/traffic_light_faces/923
#   inflating: validate.zarr/traffic_light_faces/924
#   inflating: validate.zarr/traffic_light_faces/925
#   inflating: validate.zarr/traffic_light_faces/926
#   inflating: validate.zarr/traffic_light_faces/927
#   inflating: validate.zarr/traffic_light_faces/928
#   inflating: validate.zarr/traffic_light_faces/929
#   inflating: validate.zarr/traffic_light_faces/93
#   inflating: validate.zarr/traffic_light_faces/930
#   inflating: validate.zarr/traffic_light_faces/931
#   inflating: validate.zarr/traffic_light_faces/932
#   inflating: validate.zarr/traffic_light_faces/933
#   inflating: validate.zarr/traffic_light_faces/934
#   inflating: validate.zarr/traffic_light_faces/935
#   inflating: validate.zarr/traffic_light_faces/936
#   inflating: validate.zarr/traffic_light_faces/937
#   inflating: validate.zarr/traffic_light_faces/938
#   inflating: validate.zarr/traffic_light_faces/939
#   inflating: validate.zarr/traffic_light_faces/94
#   inflating: validate.zarr/traffic_light_faces/940
#   inflating: validate.zarr/traffic_light_faces/941
#   inflating: validate.zarr/traffic_light_faces/942
#   inflating: validate.zarr/traffic_light_faces/943
#   inflating: validate.zarr/traffic_light_faces/944
#   inflating: validate.zarr/traffic_light_faces/945
#   inflating: validate.zarr/traffic_light_faces/946
#   inflating: validate.zarr/traffic_light_faces/947
#   inflating: validate.zarr/traffic_light_faces/948
#   inflating: validate.zarr/traffic_light_faces/949
#   inflating: validate.zarr/traffic_light_faces/95
#   inflating: validate.zarr/traffic_light_faces/950
#   inflating: validate.zarr/traffic_light_faces/951
#   inflating: validate.zarr/traffic_light_faces/952
#   inflating: validate.zarr/traffic_light_faces/953
#   inflating: validate.zarr/traffic_light_faces/954
#   inflating: validate.zarr/traffic_light_faces/955
#   inflating: validate.zarr/traffic_light_faces/956
#   inflating: validate.zarr/traffic_light_faces/957
#   inflating: validate.zarr/traffic_light_faces/958
#   inflating: validate.zarr/traffic_light_faces/959
#   inflating: validate.zarr/traffic_light_faces/96
#   inflating: validate.zarr/traffic_light_faces/960
#   inflating: validate.zarr/traffic_light_faces/961
#   inflating: validate.zarr/traffic_light_faces/962
#   inflating: validate.zarr/traffic_light_faces/963
#   inflating: validate.zarr/traffic_light_faces/964
#   inflating: validate.zarr/traffic_light_faces/965
#   inflating: validate.zarr/traffic_light_faces/966
#   inflating: validate.zarr/traffic_light_faces/967
#   inflating: validate.zarr/traffic_light_faces/968
#   inflating: validate.zarr/traffic_light_faces/969
#   inflating: validate.zarr/traffic_light_faces/97
#   inflating: validate.zarr/traffic_light_faces/970
#   inflating: validate.zarr/traffic_light_faces/971
#   inflating: validate.zarr/traffic_light_faces/972
#   inflating: validate.zarr/traffic_light_faces/973
#   inflating: validate.zarr/traffic_light_faces/974
#   inflating: validate.zarr/traffic_light_faces/975
#   inflating: validate.zarr/traffic_light_faces/976
#   inflating: validate.zarr/traffic_light_faces/977
#   inflating: validate.zarr/traffic_light_faces/978
#   inflating: validate.zarr/traffic_light_faces/979
#   inflating: validate.zarr/traffic_light_faces/98
#   inflating: validate.zarr/traffic_light_faces/980
#   inflating: validate.zarr/traffic_light_faces/981
#   inflating: validate.zarr/traffic_light_faces/982
#   inflating: validate.zarr/traffic_light_faces/983
#   inflating: validate.zarr/traffic_light_faces/984
#   inflating: validate.zarr/traffic_light_faces/985
#   inflating: validate.zarr/traffic_light_faces/986
#   inflating: validate.zarr/traffic_light_faces/987
#   inflating: validate.zarr/traffic_light_faces/988
#   inflating: validate.zarr/traffic_light_faces/989
#   inflating: validate.zarr/traffic_light_faces/99
#   inflating: validate.zarr/traffic_light_faces/990
#   inflating: validate.zarr/traffic_light_faces/991
#   inflating: validate.zarr/traffic_light_faces/992
#   inflating: validate.zarr/traffic_light_faces/993
#   inflating: validate.zarr/traffic_light_faces/994
#   inflating: validate.zarr/traffic_light_faces/995
#   inflating: validate.zarr/traffic_light_faces/996
#   inflating: validate.zarr/traffic_light_faces/997
#   inflating: validate.zarr/traffic_light_faces/998
#   inflating: validate.zarr/traffic_light_faces/999

# %%
# %cd '/content/lyft-motion-prediction-autonomous-vehicles/scenes/'
# !pwd
# !ls
# Out:
# /content
# /content/lyft-motion-prediction-autonomous-vehicles/scenes
# mask.npz  sample.zarr  scenes.zip  test.zarr  train.zarr  validate.zarr

# %%
# %rm -r sample.zarr/
# %rm scenes.zip

# %%
# %cd ..
# !pwd
# !ls
# Out:
# /content/lyft-motion-prediction-autonomous-vehicles
# /content/lyft-motion-prediction-autonomous-vehicles
# scenes

# %%
os.makedirs('/content/lyft-motion-prediction-autonomous-vehicles/aerial_map/', exist_ok=True)
os.chdir('/content/lyft-motion-prediction-autonomous-vehicles/aerial_map/')

# !wget --header="Host: storage.googleapis.com" --header="User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9" --header="Accept-Language: en-US,en;q=0.9,vi-VN;q=0.8,vi;q=0.7" --header="Referer: https://www.kaggle.com/" "https://storage.googleapis.com/kaggle-competitions-data/kaggle-v2/19990/1472735/compressed/aerial_map.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1603023069&Signature=lntWmsWC11llPiBgzk%2FOorFVBN2ZB2%2BaPeW3V6Tc6ACFRNUK%2B1yDFKV%2Bj07tWh6%2Bvd4redESIQE8WQTZq9qGQUl41KnJAB87u%2BsTOyD1jz%2BZchjbK2Nbz81h7fM2jacY%2F4a6J6O8XGPVU8u0Mta3s9X9qGbFTUtCsWO1r3LaldJCnC8KzTqeXlbcYKUTeYc%2FUOGFD%2BaP0fPOtRtfqwDIhbm2xMOhRk5PaKtLl5Kdv4EPk95bLJFnoq%2Foxzuo436gnMs9yw1Fv25QNaQLtCaJk7ghEDNYHXd7SvjoHYF8F40W%2BOOE%2F1FuaY1ZC%2BCl3eEnRFWCHGroSC90DCVsRtYM5g%3D%3D&response-content-disposition=attachment%3B+filename%3Daerial_map.zip" -c -O 'aerial_map.zip'
# !unzip ./aerial_map.zip
# Out:
# --2020-10-16 00:38:19--  https://storage.googleapis.com/kaggle-competitions-data/kaggle-v2/19990/1472735/compressed/aerial_map.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1603023069&Signature=lntWmsWC11llPiBgzk%2FOorFVBN2ZB2%2BaPeW3V6Tc6ACFRNUK%2B1yDFKV%2Bj07tWh6%2Bvd4redESIQE8WQTZq9qGQUl41KnJAB87u%2BsTOyD1jz%2BZchjbK2Nbz81h7fM2jacY%2F4a6J6O8XGPVU8u0Mta3s9X9qGbFTUtCsWO1r3LaldJCnC8KzTqeXlbcYKUTeYc%2FUOGFD%2BaP0fPOtRtfqwDIhbm2xMOhRk5PaKtLl5Kdv4EPk95bLJFnoq%2Foxzuo436gnMs9yw1Fv25QNaQLtCaJk7ghEDNYHXd7SvjoHYF8F40W%2BOOE%2F1FuaY1ZC%2BCl3eEnRFWCHGroSC90DCVsRtYM5g%3D%3D&response-content-disposition=attachment%3B+filename%3Daerial_map.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.193.128, 172.217.204.128, 172.217.203.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.193.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2403101722 (2.2G) [application/zip]
# Saving to: ‘aerial_map.zip’
#
# aerial_map.zip      100%[===================>]   2.24G   149MB/s    in 20s
#
# 2020-10-16 00:38:39 (113 MB/s) - ‘aerial_map.zip’ saved [2403101722/2403101722]
#
# Archive:  ./aerial_map.zip
#   inflating: LICENSE
#   inflating: aerial_map.png
#   inflating: feedback.txt
#   inflating: nearmap_images/lyft1006.tfw
#   inflating: nearmap_images/lyft1007.tfw
#   inflating: nearmap_images/lyft1008.tfw
#   inflating: nearmap_images/lyft1009.tfw
#   inflating: nearmap_images/lyft1010.tfw
#   inflating: nearmap_images/lyft1011.tfw
#   inflating: nearmap_images/lyft1012.tfw
#   inflating: nearmap_images/lyft1013.tfw
#   inflating: nearmap_images/lyft1014.tfw
#   inflating: nearmap_images/lyft1015.tfw
#   inflating: nearmap_images/lyft1016.tfw
#   inflating: nearmap_images/lyft1017.tfw
#   inflating: nearmap_images/lyft1018.tfw
#   inflating: nearmap_images/lyft1019.tfw
#   inflating: nearmap_images/lyft1020.tfw
#   inflating: nearmap_images/lyft1021.tfw
#   inflating: nearmap_images/lyft1022.tfw
#   inflating: nearmap_images/lyft1023.tfw
#   inflating: nearmap_images/lyft1107.tfw
#   inflating: nearmap_images/lyft1108.tfw
#   inflating: nearmap_images/lyft1109.tfw
#   inflating: nearmap_images/lyft1110.tfw
#   inflating: nearmap_images/lyft1111.tfw
#   inflating: nearmap_images/lyft1112.tfw
#   inflating: nearmap_images/lyft1113.tfw
#   inflating: nearmap_images/lyft1114.tfw
#   inflating: nearmap_images/lyft1115.tfw
#   inflating: nearmap_images/lyft1116.tfw
#   inflating: nearmap_images/lyft1117.tfw
#   inflating: nearmap_images/lyft1118.tfw
#   inflating: nearmap_images/lyft1119.tfw
#   inflating: nearmap_images/lyft1120.tfw
#   inflating: nearmap_images/lyft1121.tfw
#   inflating: nearmap_images/lyft1122.tfw
#   inflating: nearmap_images/lyft1123.tfw
#   inflating: nearmap_images/lyft1208.tfw
#   inflating: nearmap_images/lyft1209.tfw
#   inflating: nearmap_images/lyft1210.tfw
#   inflating: nearmap_images/lyft1211.tfw
#   inflating: nearmap_images/lyft1212.tfw
#   inflating: nearmap_images/lyft1213.tfw
#   inflating: nearmap_images/lyft1214.tfw
#   inflating: nearmap_images/lyft1215.tfw
#   inflating: nearmap_images/lyft1216.tfw
#   inflating: nearmap_images/lyft1217.tfw
#   inflating: nearmap_images/lyft1218.tfw
#   inflating: nearmap_images/lyft1219.tfw
#   inflating: nearmap_images/lyft1220.tfw
#   inflating: nearmap_images/lyft1221.tfw
#   inflating: nearmap_images/lyft1222.tfw
#   inflating: nearmap_images/lyft1223.tfw
#   inflating: nearmap_images/lyft1224.tfw
#   inflating: nearmap_images/lyft1310.tfw
#   inflating: nearmap_images/lyft1311.tfw
#   inflating: nearmap_images/lyft1312.tfw
#   inflating: nearmap_images/lyft1313.tfw
#   inflating: nearmap_images/lyft1314.tfw
#   inflating: nearmap_images/lyft1315.tfw
#   inflating: nearmap_images/lyft1316.tfw
#   inflating: nearmap_images/lyft1317.tfw
#   inflating: nearmap_images/lyft1318.tfw
#   inflating: nearmap_images/lyft1319.tfw
#   inflating: nearmap_images/lyft1320.tfw
#   inflating: nearmap_images/lyft1321.tfw
#   inflating: nearmap_images/lyft1322.tfw
#   inflating: nearmap_images/lyft1323.tfw
#   inflating: nearmap_images/lyft1324.tfw
#   inflating: nearmap_images/lyft1325.tfw
#   inflating: nearmap_images/lyft1326.tfw
#   inflating: nearmap_images/lyft1411.tfw
#   inflating: nearmap_images/lyft1412.tfw
#   inflating: nearmap_images/lyft1413.tfw
#   inflating: nearmap_images/lyft1414.tfw
#   inflating: nearmap_images/lyft1415.tfw
#   inflating: nearmap_images/lyft1416.tfw
#   inflating: nearmap_images/lyft1417.tfw
#   inflating: nearmap_images/lyft1418.tfw
#   inflating: nearmap_images/lyft1419.tfw
#   inflating: nearmap_images/lyft1420.tfw
#   inflating: nearmap_images/lyft1421.tfw
#   inflating: nearmap_images/lyft1422.tfw
#   inflating: nearmap_images/lyft1423.tfw
#   inflating: nearmap_images/lyft1424.tfw
#   inflating: nearmap_images/lyft1425.tfw
#   inflating: nearmap_images/lyft1426.tfw
#   inflating: nearmap_images/lyft1427.tfw
#   inflating: nearmap_images/lyft1513.tfw
#   inflating: nearmap_images/lyft1514.tfw
#   inflating: nearmap_images/lyft1515.tfw
#   inflating: nearmap_images/lyft1516.tfw
#   inflating: nearmap_images/lyft1517.tfw
#   inflating: nearmap_images/lyft1518.tfw
#   inflating: nearmap_images/lyft1519.tfw
#   inflating: nearmap_images/lyft1520.tfw
#   inflating: nearmap_images/lyft1521.tfw
#   inflating: nearmap_images/lyft1522.tfw
#   inflating: nearmap_images/lyft1523.tfw
#   inflating: nearmap_images/lyft1524.tfw
#   inflating: nearmap_images/lyft1525.tfw
#   inflating: nearmap_images/lyft1526.tfw
#   inflating: nearmap_images/lyft1527.tfw
#   inflating: nearmap_images/lyft1528.tfw
#   inflating: nearmap_images/lyft1528.tif
#   inflating: nearmap_images/lyft1614.tfw
#   inflating: nearmap_images/lyft1615.tfw
#   inflating: nearmap_images/lyft1616.tfw
#   inflating: nearmap_images/lyft1617.tfw
#   inflating: nearmap_images/lyft1618.tfw
#   inflating: nearmap_images/lyft1619.tfw
#   inflating: nearmap_images/lyft1620.tfw
#   inflating: nearmap_images/lyft1621.tfw
#   inflating: nearmap_images/lyft1622.tfw
#   inflating: nearmap_images/lyft1623.tfw
#   inflating: nearmap_images/lyft1624.tfw
#   inflating: nearmap_images/lyft1625.tfw
#   inflating: nearmap_images/lyft1626.tfw
#   inflating: nearmap_images/lyft1627.tfw
#   inflating: nearmap_images/lyft1628.tfw
#   inflating: nearmap_images/lyft1716.tfw
#   inflating: nearmap_images/lyft1717.tfw
#   inflating: nearmap_images/lyft1718.tfw
#   inflating: nearmap_images/lyft1719.tfw
#   inflating: nearmap_images/lyft1720.tfw
#   inflating: nearmap_images/lyft1721.tfw
#   inflating: nearmap_images/lyft1722.tfw
#   inflating: nearmap_images/lyft1723.tfw
#   inflating: nearmap_images/lyft1724.tfw
#   inflating: nearmap_images/lyft1725.tfw
#   inflating: nearmap_images/lyft1726.tfw
#   inflating: nearmap_images/lyft1727.tfw
#   inflating: nearmap_images/lyft1817.tfw
#   inflating: nearmap_images/lyft1817.tif
#   inflating: nearmap_images/lyft1818.tfw
#   inflating: nearmap_images/lyft1818.tif
#   inflating: nearmap_images/lyft1819.tfw
#   inflating: nearmap_images/lyft1820.tfw
#   inflating: nearmap_images/lyft1821.tfw
#   inflating: nearmap_images/lyft1822.tfw
#   inflating: nearmap_images/lyft1823.tfw
#   inflating: nearmap_images/lyft1824.tfw
#   inflating: nearmap_images/lyft1824.tif
#   inflating: nearmap_images/lyft1825.tfw
#   inflating: nearmap_images/lyft1825.tif
#   inflating: nearmap_images/lyft1826.tfw
#   inflating: nearmap_images/lyft1826.tif
#   inflating: nearmap_images/lyft1827.tfw
#   inflating: nearmap_images/lyft1827.tif
#   inflating: nearmap_images/lyft1919.tfw
#   inflating: nearmap_images/lyft1919.tif
#   inflating: nearmap_images/lyft1920.tfw
#   inflating: nearmap_images/lyft1920.tif
#   inflating: nearmap_images/lyft1921.tfw
#   inflating: nearmap_images/lyft1921.tif
#   inflating: nearmap_images/lyft1922.tfw
#   inflating: nearmap_images/lyft1922.tif
#   inflating: nearmap_images/lyft1923.tfw
#   inflating: nearmap_images/lyft1923.tif
#   inflating: nearmap_images/lyft1924.tfw
#   inflating: nearmap_images/lyft1924.tif
#   inflating: nearmap_images/lyft1925.tfw
#   inflating: nearmap_images/lyft1925.tif
#   inflating: nearmap_images/lyft1926.tfw
#   inflating: nearmap_images/lyft1926.tif
#   inflating: nearmap_images/lyft2019.tfw
#   inflating: nearmap_images/lyft2019.tif
#   inflating: nearmap_images/lyft2020.tfw
#   inflating: nearmap_images/lyft2020.tif
#   inflating: nearmap_images/lyft2021.tfw
#   inflating: nearmap_images/lyft2021.tif
#   inflating: nearmap_images/lyft2022.tfw
#   inflating: nearmap_images/lyft2022.tif
#   inflating: nearmap_images/lyft2023.tfw
#   inflating: nearmap_images/lyft2023.tif
#   inflating: nearmap_images/lyft2024.tfw
#   inflating: nearmap_images/lyft2024.tif
#   inflating: nearmap_images/lyft2025.tfw
#   inflating: nearmap_images/lyft2025.tif
#   inflating: nearmap_images/lyft2120.tfw
#   inflating: nearmap_images/lyft2120.tif
#   inflating: nearmap_images/lyft2121.tfw
#   inflating: nearmap_images/lyft2121.tif
#   inflating: nearmap_images/lyft2122.tfw
#   inflating: nearmap_images/lyft2122.tif
#   inflating: nearmap_images/lyft2123.tfw
#   inflating: nearmap_images/lyft2123.tif
#   inflating: nearmap_images/lyft2124.tfw
#   inflating: nearmap_images/lyft2124.tif
#   inflating: nearmap_images/lyft2221.tfw
#   inflating: nearmap_images/lyft2221.tif
#   inflating: nearmap_images/lyft2222.tfw
#   inflating: nearmap_images/lyft2222.tif
#   inflating: nearmap_images/lyft2223.tfw
#   inflating: nearmap_images/lyft2223.tif
#   inflating: nearmap_images/lyft2321.tfw
#   inflating: nearmap_images/lyft2321.tif
#   inflating: nearmap_images/lyft2322.tfw
#   inflating: nearmap_images/lyft2322.tif
#   inflating: nearmap_images/lyft311.tfw
#   inflating: nearmap_images/lyft311.tif
#   inflating: nearmap_images/lyft312.tfw
#   inflating: nearmap_images/lyft312.tif
#   inflating: nearmap_images/lyft313.tfw
#   inflating: nearmap_images/lyft314.tfw
#   inflating: nearmap_images/lyft314.tif
#   inflating: nearmap_images/lyft315.tfw
#   inflating: nearmap_images/lyft315.tif
#   inflating: nearmap_images/lyft316.tfw
#   inflating: nearmap_images/lyft316.tif
#   inflating: nearmap_images/lyft317.tfw
#   inflating: nearmap_images/lyft317.tif
#   inflating: nearmap_images/lyft411.tfw
#   inflating: nearmap_images/lyft411.tif
#   inflating: nearmap_images/lyft412.tfw
#   inflating: nearmap_images/lyft412.tif
#   inflating: nearmap_images/lyft413.tfw
#   inflating: nearmap_images/lyft413.tif
#   inflating: nearmap_images/lyft414.tfw
#   inflating: nearmap_images/lyft414.tif
#   inflating: nearmap_images/lyft415.tfw
#   inflating: nearmap_images/lyft415.tif
#   inflating: nearmap_images/lyft416.tfw
#   inflating: nearmap_images/lyft416.tif
#   inflating: nearmap_images/lyft417.tfw
#   inflating: nearmap_images/lyft417.tif
#   inflating: nearmap_images/lyft418.tfw
#   inflating: nearmap_images/lyft418.tif
#   inflating: nearmap_images/lyft419.tfw
#   inflating: nearmap_images/lyft419.tif
#   inflating: nearmap_images/lyft420.tfw
#   inflating: nearmap_images/lyft420.tif
#   inflating: nearmap_images/lyft510.tfw
#   inflating: nearmap_images/lyft510.tif
#   inflating: nearmap_images/lyft511.tfw
#   inflating: nearmap_images/lyft512.tfw
#   inflating: nearmap_images/lyft512.tif
#   inflating: nearmap_images/lyft513.tfw
#   inflating: nearmap_images/lyft513.tif
#   inflating: nearmap_images/lyft514.tfw
#   inflating: nearmap_images/lyft514.tif
#   inflating: nearmap_images/lyft515.tfw
#   inflating: nearmap_images/lyft515.tif
#   inflating: nearmap_images/lyft516.tfw
#   inflating: nearmap_images/lyft516.tif
#   inflating: nearmap_images/lyft517.tfw
#   inflating: nearmap_images/lyft517.tif
#   inflating: nearmap_images/lyft518.tfw
#   inflating: nearmap_images/lyft518.tif
#   inflating: nearmap_images/lyft519.tfw
#   inflating: nearmap_images/lyft519.tif
#   inflating: nearmap_images/lyft520.tfw
#   inflating: nearmap_images/lyft520.tif
#   inflating: nearmap_images/lyft609.tfw
#   inflating: nearmap_images/lyft609.tif
#   inflating: nearmap_images/lyft610.tfw
#   inflating: nearmap_images/lyft610.tif
#   inflating: nearmap_images/lyft611.tfw
#   inflating: nearmap_images/lyft611.tif
#   inflating: nearmap_images/lyft612.tfw
#   inflating: nearmap_images/lyft612.tif
#   inflating: nearmap_images/lyft613.tfw
#   inflating: nearmap_images/lyft613.tif
#   inflating: nearmap_images/lyft614.tfw
#   inflating: nearmap_images/lyft614.tif
#   inflating: nearmap_images/lyft615.tfw
#   inflating: nearmap_images/lyft615.tif
#   inflating: nearmap_images/lyft616.tfw
#   inflating: nearmap_images/lyft616.tif
#   inflating: nearmap_images/lyft617.tfw
#   inflating: nearmap_images/lyft617.tif
#   inflating: nearmap_images/lyft618.tfw
#   inflating: nearmap_images/lyft618.tif
#   inflating: nearmap_images/lyft619.tfw
#   inflating: nearmap_images/lyft619.tif
#   inflating: nearmap_images/lyft620.tfw
#   inflating: nearmap_images/lyft708.tfw
#   inflating: nearmap_images/lyft708.tif
#   inflating: nearmap_images/lyft709.tfw
#   inflating: nearmap_images/lyft709.tif
#   inflating: nearmap_images/lyft710.tfw
#   inflating: nearmap_images/lyft710.tif
#   inflating: nearmap_images/lyft711.tfw
#   inflating: nearmap_images/lyft712.tfw
#   inflating: nearmap_images/lyft712.tif
#   inflating: nearmap_images/lyft713.tfw
#   inflating: nearmap_images/lyft713.tif
#   inflating: nearmap_images/lyft714.tfw
#   inflating: nearmap_images/lyft714.tif
#   inflating: nearmap_images/lyft715.tfw
#   inflating: nearmap_images/lyft715.tif
#   inflating: nearmap_images/lyft716.tfw
#   inflating: nearmap_images/lyft716.tif
#   inflating: nearmap_images/lyft717.tfw
#   inflating: nearmap_images/lyft717.tif
#   inflating: nearmap_images/lyft718.tfw
#   inflating: nearmap_images/lyft718.tif
#   inflating: nearmap_images/lyft719.tfw
#   inflating: nearmap_images/lyft719.tif
#   inflating: nearmap_images/lyft720.tfw
#   inflating: nearmap_images/lyft720.tif
#   inflating: nearmap_images/lyft721.tfw
#   inflating: nearmap_images/lyft721.tif
#   inflating: nearmap_images/lyft808.tfw
#   inflating: nearmap_images/lyft808.tif
#   inflating: nearmap_images/lyft809.tfw
#   inflating: nearmap_images/lyft809.tif
#   inflating: nearmap_images/lyft810.tfw
#   inflating: nearmap_images/lyft810.tif
#   inflating: nearmap_images/lyft811.tfw
#   inflating: nearmap_images/lyft811.tif
#   inflating: nearmap_images/lyft812.tfw
#   inflating: nearmap_images/lyft812.tif
#   inflating: nearmap_images/lyft813.tfw
#   inflating: nearmap_images/lyft813.tif
#   inflating: nearmap_images/lyft814.tfw
#   inflating: nearmap_images/lyft814.tif
#   inflating: nearmap_images/lyft815.tfw
#   inflating: nearmap_images/lyft815.tif
#   inflating: nearmap_images/lyft816.tfw
#   inflating: nearmap_images/lyft816.tif
#   inflating: nearmap_images/lyft817.tfw
#   inflating: nearmap_images/lyft817.tif
#   inflating: nearmap_images/lyft818.tfw
#   inflating: nearmap_images/lyft818.tif
#   inflating: nearmap_images/lyft819.tfw
#   inflating: nearmap_images/lyft819.tif
#   inflating: nearmap_images/lyft820.tfw
#   inflating: nearmap_images/lyft820.tif
#   inflating: nearmap_images/lyft821.tfw
#   inflating: nearmap_images/lyft821.tif
#   inflating: nearmap_images/lyft822.tfw
#   inflating: nearmap_images/lyft822.tif
#   inflating: nearmap_images/lyft907.tfw
#   inflating: nearmap_images/lyft908.tfw
#   inflating: nearmap_images/lyft908.tif
#   inflating: nearmap_images/lyft909.tfw
#   inflating: nearmap_images/lyft909.tif
#   inflating: nearmap_images/lyft910.tfw
#   inflating: nearmap_images/lyft910.tif
#   inflating: nearmap_images/lyft911.tfw
#   inflating: nearmap_images/lyft911.tif
#   inflating: nearmap_images/lyft912.tfw
#   inflating: nearmap_images/lyft912.tif
#   inflating: nearmap_images/lyft913.tfw
#   inflating: nearmap_images/lyft913.tif
#   inflating: nearmap_images/lyft914.tfw
#   inflating: nearmap_images/lyft914.tif
#   inflating: nearmap_images/lyft915.tfw
#   inflating: nearmap_images/lyft915.tif
#   inflating: nearmap_images/lyft916.tfw
#   inflating: nearmap_images/lyft916.tif
#   inflating: nearmap_images/lyft917.tfw
#   inflating: nearmap_images/lyft917.tif
#   inflating: nearmap_images/lyft918.tfw
#   inflating: nearmap_images/lyft918.tif
#   inflating: nearmap_images/lyft919.tfw
#   inflating: nearmap_images/lyft919.tif
#   inflating: nearmap_images/lyft920.tfw
#   inflating: nearmap_images/lyft920.tif
#   inflating: nearmap_images/lyft921.tfw
#   inflating: nearmap_images/lyft921.tif
#   inflating: nearmap_images/lyft922.tfw
#   inflating: nearmap_images/lyft922.tif

# %%
# %rm -r aerial_map.zip

# %%
# %cd ..
# !pwd
# !ls
# Out:
# /content/lyft-motion-prediction-autonomous-vehicles
# /content/lyft-motion-prediction-autonomous-vehicles
# aerial_map  scenes

# %%
os.makedirs('/content/lyft-motion-prediction-autonomous-vehicles/semantic_map/', exist_ok=True)
os.chdir('/content/lyft-motion-prediction-autonomous-vehicles/semantic_map/')

# !wget --header="Host: storage.googleapis.com" --header="User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9" --header="Accept-Language: en-US,en;q=0.9,vi-VN;q=0.8,vi;q=0.7" --header="Referer: https://www.kaggle.com/" "https://storage.googleapis.com/kaggle-competitions-data/kaggle-v2/19990/1472735/upload/semantic_map.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1603023157&Signature=hUJCXvnR3ms%2FGecSic2Ga5mZ72mdqWU%2F%2FKffozvdb61yd%2BoqEJ%2F3Knoh854Yj4LZwQllMq2bCdt2xeIahXttT51WGSkwWJlbE7tlTuOXJmYzPLgRYywQo25a%2FvQ8qYnoMO6CmyGe9BkGSPyYOTwM2sE3SB6J0pAR5YQEMZHefR2odrT77Y8vlQWMU%2BMvc%2Fl5c5uYgKaQvgRC2NZiaIfmpnZiciJf8wdK84XPKt0jLYRrx%2BWJCHMVdEc2wc3fwn0Bn7sTbd%2B1S8mQgqBMgdmbqq1QQ4r9qKu6XwYWQ0cCsrwW9FmSDMqZ5%2BRxmZo7rC2kGJEfHg2ylDFrrf945wTltQ%3D%3D&response-content-disposition=attachment%3B+filename%3Dsemantic_map.zip" -c -O 'semantic_map.zip'
# !unzip ./semantic_map.zip
# Out:
# --2020-10-16 00:39:04--  https://storage.googleapis.com/kaggle-competitions-data/kaggle-v2/19990/1472735/upload/semantic_map.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1603023157&Signature=hUJCXvnR3ms%2FGecSic2Ga5mZ72mdqWU%2F%2FKffozvdb61yd%2BoqEJ%2F3Knoh854Yj4LZwQllMq2bCdt2xeIahXttT51WGSkwWJlbE7tlTuOXJmYzPLgRYywQo25a%2FvQ8qYnoMO6CmyGe9BkGSPyYOTwM2sE3SB6J0pAR5YQEMZHefR2odrT77Y8vlQWMU%2BMvc%2Fl5c5uYgKaQvgRC2NZiaIfmpnZiciJf8wdK84XPKt0jLYRrx%2BWJCHMVdEc2wc3fwn0Bn7sTbd%2B1S8mQgqBMgdmbqq1QQ4r9qKu6XwYWQ0cCsrwW9FmSDMqZ5%2BRxmZo7rC2kGJEfHg2ylDFrrf945wTltQ%3D%3D&response-content-disposition=attachment%3B+filename%3Dsemantic_map.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.31.128, 74.125.141.128, 173.194.214.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.31.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2065996 (2.0M) [application/zip]
# Saving to: ‘semantic_map.zip’
#
# semantic_map.zip    100%[===================>]   1.97M  --.-KB/s    in 0.01s
#
# 2020-10-16 00:39:04 (149 MB/s) - ‘semantic_map.zip’ saved [2065996/2065996]
#
# Archive:  ./semantic_map.zip
#   inflating: feedback.txt
#   inflating: semantic_map.pb
#   inflating: LICENSE

# %%
# %rm -r semantic_map.zip
# %cd ..
# !pwd
# !ls
# Out:
# /content/lyft-motion-prediction-autonomous-vehicles
# /content/lyft-motion-prediction-autonomous-vehicles
# aerial_map  scenes  semantic_map

# %% [markdown]
# # Environment setup
#
#  - Please add [pestipeti/lyft-l5kit-unofficial-fix](https://www.kaggle.com/pestipeti/lyft-l5kit-unofficial-fix) as utility script.
#     - Official utility script "[philculliton/kaggle-l5kit](https://www.kaggle.com/mathurinache/kaggle-l5kit)" does not work with pytorch GPU.
#
# Click "File" botton on top-left, and choose "Add utility script". For the pop-up search window, you need to remove "Your Work" filter, and search [pestipeti/lyft-l5kit-unofficial-fix](https://www.kaggle.com/pestipeti/lyft-l5kit-unofficial-fix) on top-right of the search window. Then you can add the kaggle-l5kit utility script. It is much faster to do this rather than !pip install l5kit every time you run the notebook.
#
# If successful, you can see "usr/lib/lyft-l5kit-unofficial-fix" is added to the "Data" section of this kernel page on right side of the kernel.
#
# - Also please add [pretrained baseline model](https://www.kaggle.com/huanvo/lyft-pretrained-model-hv)
#
# Click on the button "Add data" in the "Data" section and search for lyft-pretrained-model-hv. If you find the model useful, please upvote it as well.

# %%
# this script transports l5kit and dependencies
# !pip -q install pymap3d==2.1.0 
# !pip -q install protobuf==3.12.2 
# !pip -q install transforms3d 
# !pip -q install zarr 
# !pip -q install ptable

# !pip -q install --no-dependencies l5kit
# !pip install adamp
# Out:
# Requirement already satisfied: adamp in /usr/local/lib/python3.6/dist-packages (0.3.0)

# %%
from typing import Dict

from tempfile import gettempdir
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
from torch import nn, optim
from torch.utils.data import DataLoader
from torchvision.models.resnet import resnet50, resnet18, resnet34, resnet101
from tqdm import tqdm

import l5kit
from l5kit.configs import load_config_data
from l5kit.data import LocalDataManager, ChunkedDataset
from l5kit.dataset import AgentDataset, EgoDataset
from l5kit.rasterization import build_rasterizer
from l5kit.evaluation import write_pred_csv, compute_metrics_csv, read_gt_csv, create_chopped_dataset
from l5kit.evaluation.chop_dataset import MIN_FUTURE_STEPS
from l5kit.evaluation.metrics import neg_multi_log_likelihood, time_displace
from l5kit.geometry import transform_points
from l5kit.visualization import PREDICTED_POINTS_COLOR, TARGET_POINTS_COLOR, draw_trajectory
from prettytable import PrettyTable
from pathlib import Path

from adamp import AdamP

import matplotlib.pyplot as plt

import os
import random
import time

import warnings
warnings.filterwarnings("ignore")

# %%
l5kit.__version__
# Out:
# '1.1.0'

# %%
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    
set_seed(42)

# %% [markdown]
# ## Configs

# %%
# --- Lyft configs ---
cfg = {
    'format_version': 4,
    'data_path': "/content/lyft-motion-prediction-autonomous-vehicles",
    'model_params': {
        'model_architecture': 'resnet18',
        'history_num_frames': 10,
        'history_step_size': 1,
        'history_delta_time': 0.1,
        'future_num_frames': 50,
        'future_step_size': 1,
        'future_delta_time': 0.1,
        'model_name': "model_resnet18",
        'lr': 1e-4,
        'weight_path': False,
        'train': True,
        'predict': False
    },

    'raster_params': {
        'raster_size': [224, 224],
        'pixel_size': [0.5, 0.5],
        'ego_center': [0.25, 0.5],
        'map_type': 'py_semantic',
        'satellite_map_key': 'aerial_map/aerial_map.png',
        'semantic_map_key': 'semantic_map/semantic_map.pb',
        'dataset_meta_key': 'meta.json',
        'filter_agents_threshold': 0.5
    },

    'train_data_loader': {
        'key': 'scenes/train.zarr',
        'batch_size': 16,
        'shuffle': True,
        'num_workers': 0
    },
    
    'test_data_loader': {
        'key': 'scenes/test.zarr',
        'batch_size': 32,
        'shuffle': False,
        'num_workers': 0
    },

    'train_params': {
        'max_num_steps': 100000,
        'checkpoint_every_n_steps': 10000,
    }
}

# %% [markdown]
# Couple of things to note:
#
#  - **model_architecture:** you can put 'resnet18', 'resnet34' or 'resnet50'. For the pretrained model we use resnet18 so we need to use 'resnet18' in the config.
#  - **weight_path:** path to the pretrained model. If you don't have a pretrained model and want to train from scratch, put **weight_path** = False.
#  - **model_name:** the name of the model that will be saved as output, this is only when **train**= True.
#  - **train:** True if you want to continue to train the model. Unfortunately due to Kaggle memory constraint if **train**=True then you should put **predict** = False.
#  - **predict:** True if you want to predict and submit to Kaggle. Unfortunately due to Kaggle memory constraint if you want to predict then you need  to put **train** = False.
#  - **lr:** learning rate of the model, feel free to change as you see fit. In the future I also plan to implement learning rate decay.
#  - **raster_size:** specify the size of the image, the default is [224,224]. Increase **raster_size** can improve the score. However the training time will be significantly longer.
#  - **batch_size:** number of inputs for one forward pass, again one of the parameters to tune.
#  - **max_num_steps:** the number of iterations to train, i.e. number of epochs.
#  - **checkpoint_every_n_steps:** the model will be saved at every n steps, again change this number as to how you want to keep track of the model.

# %% [markdown]
# ## Load the train and test data

# %%
# set env variable for data
DIR_INPUT = cfg["data_path"]
os.environ["L5KIT_DATA_FOLDER"] = DIR_INPUT
dm = LocalDataManager(None)

# %%
# !ls
# Out:
# drive  lyft-motion-prediction-autonomous-vehicles  sample_data

# %%
# ===== INIT TRAIN DATASET============================================================
train_cfg = cfg["train_data_loader"]
rasterizer = build_rasterizer(cfg, dm)
train_zarr = ChunkedDataset(dm.require(train_cfg["key"])).open()
train_dataset = AgentDataset(cfg, train_zarr, rasterizer)
train_dataloader = DataLoader(train_dataset, shuffle=train_cfg["shuffle"], batch_size=train_cfg["batch_size"], 
                             num_workers=train_cfg["num_workers"])
print("==================================TRAIN DATA==================================")
print(train_dataset)
# Out:
# ==================================TRAIN DATA==================================
# +------------+------------+------------+---------------+-----------------+----------------------+----------------------+----------------------+---------------------+
# | Num Scenes | Num Frames | Num Agents | Num TR lights | Total Time (hr) | Avg Frames per Scene | Avg Agents per Frame | Avg Scene Time (sec) | Avg Frame frequency |
# +------------+------------+------------+---------------+-----------------+----------------------+----------------------+----------------------+---------------------+
# |   16265    |  4039527   | 320124624  |    38735988   |      112.19     |        248.36        |        79.25         |        24.83         |        10.00        |
# +------------+------------+------------+---------------+-----------------+----------------------+----------------------+----------------------+---------------------+

# %%
#====== INIT TEST DATASET=============================================================
test_cfg = cfg["test_data_loader"]
rasterizer = build_rasterizer(cfg, dm)
test_zarr = ChunkedDataset(dm.require(test_cfg["key"])).open()
test_mask = np.load(f"{DIR_INPUT}/scenes/mask.npz")["arr_0"]
test_dataset = AgentDataset(cfg, test_zarr, rasterizer, agents_mask=test_mask)
test_dataloader = DataLoader(test_dataset,shuffle=test_cfg["shuffle"],batch_size=test_cfg["batch_size"],
                             num_workers=test_cfg["num_workers"])
print("==================================TEST DATA==================================")
print(test_dataset)
# Out:
# ==================================TEST DATA==================================
# +------------+------------+------------+---------------+-----------------+----------------------+----------------------+----------------------+---------------------+
# | Num Scenes | Num Frames | Num Agents | Num TR lights | Total Time (hr) | Avg Frames per Scene | Avg Agents per Frame | Avg Scene Time (sec) | Avg Frame frequency |
# +------------+------------+------------+---------------+-----------------+----------------------+----------------------+----------------------+---------------------+
# |   11314    |  1131400   |  88594921  |    7854144    |      31.43      |        100.00        |        78.31         |        10.00         |        10.00        |
# +------------+------------+------------+---------------+-----------------+----------------------+----------------------+----------------------+---------------------+

# %% [markdown]
# ## Simple visualization

# %% [markdown]
# Let us visualize how an input to the model looks like.

# %%
def visualize_trajectory(dataset, index, title="target_positions movement with draw_trajectory"):
    data = dataset[index]
    im = data["image"].transpose(1, 2, 0)
    im = dataset.rasterizer.to_rgb(im)
    target_positions_pixels = transform_points(data["target_positions"] + data["centroid"][:2], data["world_to_image"])
    draw_trajectory(im, target_positions_pixels, TARGET_POINTS_COLOR, radius=1, yaws=data["target_yaws"])

    plt.title(title)
    plt.imshow(im[::-1])
    plt.show()

# %%
plt.figure(figsize = (8,6))
visualize_trajectory(train_dataset, index=90)

# %% [markdown]
# ## Loss function

# %% [markdown]
# For this competition it is important to use the correct loss function when train the model. Our goal is to predict three possible paths together with the confidence score, so we need to use the loss function that takes that into account, simply using RMSE will not lead to an accurate model. More information about the loss function can be found here [negative log likelihood](https://github.com/lyft/l5kit/blob/master/competition.md).

# %%
# --- Function utils ---
# Original code from https://github.com/lyft/l5kit/blob/20ab033c01610d711c3d36e1963ecec86e8b85b6/l5kit/l5kit/evaluation/metrics.py
import numpy as np

import torch
from torch import Tensor


def pytorch_neg_multi_log_likelihood_batch(
    gt: Tensor, pred: Tensor, confidences: Tensor, avails: Tensor
) -> Tensor:
    """
    Compute a negative log-likelihood for the multi-modal scenario.
    log-sum-exp trick is used here to avoid underflow and overflow, For more information about it see:
    https://en.wikipedia.org/wiki/LogSumExp#log-sum-exp_trick_for_log-domain_calculations
    https://timvieira.github.io/blog/post/2014/02/11/exp-normalize-trick/
    https://leimao.github.io/blog/LogSumExp/
    Args:
        gt (Tensor): array of shape (bs)x(time)x(2D coords)
        pred (Tensor): array of shape (bs)x(modes)x(time)x(2D coords)
        confidences (Tensor): array of shape (bs)x(modes) with a confidence for each mode in each sample
        avails (Tensor): array of shape (bs)x(time) with the availability for each gt timestep
    Returns:
        Tensor: negative log-likelihood for this example, a single float number
    """
    assert len(pred.shape) == 4, f"expected 3D (MxTxC) array for pred, got {pred.shape}"
    batch_size, num_modes, future_len, num_coords = pred.shape

    assert gt.shape == (batch_size, future_len, num_coords), f"expected 2D (Time x Coords) array for gt, got {gt.shape}"
    assert confidences.shape == (batch_size, num_modes), f"expected 1D (Modes) array for gt, got {confidences.shape}"
    assert torch.allclose(torch.sum(confidences, dim=1), confidences.new_ones((batch_size,))), "confidences should sum to 1"
    assert avails.shape == (batch_size, future_len), f"expected 1D (Time) array for gt, got {avails.shape}"
    # assert all data are valid
    assert torch.isfinite(pred).all(), "invalid value found in pred"
    assert torch.isfinite(gt).all(), "invalid value found in gt"
    assert torch.isfinite(confidences).all(), "invalid value found in confidences"
    assert torch.isfinite(avails).all(), "invalid value found in avails"

    # convert to (batch_size, num_modes, future_len, num_coords)
    gt = torch.unsqueeze(gt, 1)  # add modes
    avails = avails[:, None, :, None]  # add modes and cords

    # error (batch_size, num_modes, future_len)
    error = torch.sum(((gt - pred) * avails) ** 2, dim=-1)  # reduce coords and use availability

    with np.errstate(divide="ignore"):  # when confidence is 0 log goes to -inf, but we're fine with it
        # error (batch_size, num_modes)
        error = torch.log(confidences) - 0.5 * torch.sum(error, dim=-1)  # reduce time

    # use max aggregator on modes for numerical stability
    # error (batch_size, num_modes)
    max_value, _ = error.max(dim=1, keepdim=True)  # error are negative at this point, so max() gives the minimum one
    error = -torch.log(torch.sum(torch.exp(error - max_value), dim=-1, keepdim=True)) - max_value  # reduce modes
    # print("error", error)
    return torch.mean(error)


def pytorch_neg_multi_log_likelihood_single(
    gt: Tensor, pred: Tensor, avails: Tensor
) -> Tensor:
    """

    Args:
        gt (Tensor): array of shape (bs)x(time)x(2D coords)
        pred (Tensor): array of shape (bs)x(time)x(2D coords)
        avails (Tensor): array of shape (bs)x(time) with the availability for each gt timestep
    Returns:
        Tensor: negative log-likelihood for this example, a single float number
    """
    # pred (bs)x(time)x(2D coords) --> (bs)x(mode=1)x(time)x(2D coords)
    # create confidence (bs)x(mode=1)
    batch_size, future_len, num_coords = pred.shape
    confidences = pred.new_ones((batch_size, 1))
    return pytorch_neg_multi_log_likelihood_batch(gt, pred.unsqueeze(1), confidences, avails)

# %% [markdown]
# ## Model

# %% [markdown]
# Next we define the baseline model. Note that this model will return three possible trajectories together with confidence score for each trajectory.

# %%
class LyftMultiModel(nn.Module):

    def __init__(self, cfg: Dict, num_modes=3):
        super().__init__()

        architecture = cfg["model_params"]["model_architecture"]
        backbone = eval(architecture)(pretrained=True, progress=True)
        self.backbone = backbone

        num_history_channels = (cfg["model_params"]["history_num_frames"] + 1) * 2
        num_in_channels = 3 + num_history_channels

        self.backbone.conv1 = nn.Conv2d(
            num_in_channels,
            self.backbone.conv1.out_channels,
            kernel_size=self.backbone.conv1.kernel_size,
            stride=self.backbone.conv1.stride,
            padding=self.backbone.conv1.padding,
            bias=False,
        )

        # This is 512 for resnet18 and resnet34;
        # And it is 2048 for the other resnets
        
        if architecture == "resnet50":
            backbone_out_features = 2048
        else:
            backbone_out_features = 512

        # X, Y coords for the future positions (output shape: batch_sizex50x2)
        self.future_len = cfg["model_params"]["future_num_frames"]
        num_targets = 2 * self.future_len

        # You can add more layers here.
        self.head = nn.Sequential(
            # nn.Dropout(0.2),
            nn.Linear(in_features=backbone_out_features, out_features=4096),
        )

        self.num_preds = num_targets * num_modes
        self.num_modes = num_modes

        self.logit = nn.Linear(4096, out_features=self.num_preds + num_modes)

    def forward(self, x):
        x = self.backbone.conv1(x)
        x = self.backbone.bn1(x)
        x = self.backbone.relu(x)
        x = self.backbone.maxpool(x)

        x = self.backbone.layer1(x)
        x = self.backbone.layer2(x)
        x = self.backbone.layer3(x)
        x = self.backbone.layer4(x)

        x = self.backbone.avgpool(x)
        x = torch.flatten(x, 1)

        x = self.head(x)
        x = self.logit(x)

        # pred (batch_size)x(modes)x(time)x(2D coords)
        # confidences (batch_size)x(modes)
        bs, _ = x.shape
        pred, confidences = torch.split(x, self.num_preds, dim=1)
        pred = pred.view(bs, self.num_modes, self.future_len, 2)
        assert confidences.shape == (bs, self.num_modes)
        confidences = torch.softmax(confidences, dim=1)
        return pred, confidences

# %%
def forward(data, model, device, criterion = pytorch_neg_multi_log_likelihood_batch):
    inputs = data["image"].to(device)
    target_availabilities = data["target_availabilities"].to(device)
    targets = data["target_positions"].to(device)
    # Forward pass
    preds, confidences = model(inputs)
    loss = criterion(targets, preds, confidences, target_availabilities)
    return loss, preds, confidences

# %% [markdown]
# Now let us initialize the model and load the pretrained weights. Note that since the pretrained model was trained on GPU, you also need to enable GPU when running this notebook.

# %%
# ==== INIT MODEL=================
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = LyftMultiModel(cfg)


optimizer = AdamP(model.parameters(), lr=cfg["model_params"]["lr"], betas=(0.9, 0.999), weight_decay=1e-2)
last_iteration = 0

#load weight if there is a pretrained model
weight_path = cfg["model_params"]["weight_path"]

if weight_path:
    checkpoint = torch.load(weight_path)
    last_iteration = checkpoint['iteration']
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

model.to(device)

print(f'device {device}')
# Out:
# device cuda:0

# %%
print(model)
# Out:
# LyftMultiModel(
#   (backbone): ResNet(
#     (conv1): Conv2d(25, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Linear(in_features=512, out_features=1000, bias=True)
#   )
#   (head): Sequential(
#     (0): Linear(in_features=512, out_features=4096, bias=True)
#   )
#   (logit): Linear(in_features=4096, out_features=303, bias=True)
# )

# %% [markdown]
# ## Training loop

# %% [markdown]
# Next let us implement the training loop, when the **train** parameter is set to True.

# %%
# ==== TRAINING LOOP =========================================================
if cfg["model_params"]["train"]:
    
    tr_it = iter(train_dataloader)
    
    progress_bar = tqdm(range(last_iteration, cfg["train_params"]["max_num_steps"]))
    num_iter = cfg["train_params"]["max_num_steps"]
    losses_train = []
    iterations = []
    metrics = []
    times = []
    model_name = cfg["model_params"]["model_name"]
    start = time.time()
    for i in progress_bar:
        try:
            data = next(tr_it)
        except StopIteration:
            tr_it = iter(train_dataloader)
            data = next(tr_it)
        model.train()
        torch.set_grad_enabled(True)
        
        loss, _, _ = forward(data, model, device)

        # Backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        losses_train.append(loss.item())

        progress_bar.set_description(f"loss: {loss.item():.2f} loss(avg): {np.mean(losses_train):.2f}")
        if (i + 1) % cfg['train_params']['checkpoint_every_n_steps'] == 0:
            torch.save({'iteration': i + 1,
                        'model_state_dict': model.state_dict(), 
                        'optimizer_state_dict': optimizer.state_dict()},
                        f'{model_name}_raster {cfg["raster_params"]["raster_size"][0]}_step {i + 1}_loss {np.mean(losses_train):.2f}.pth')
            iterations.append(i)
            metrics.append(np.mean(losses_train))
            times.append((time.time()-start)/60)

    results = pd.DataFrame({'iterations': iterations, 'metrics (avg)': metrics, 'elapsed_time (mins)': times})
    results.to_csv(f"train_metrics_{model_name}_{num_iter}.csv", index = False)
    print(f"Total training time is {(time.time()-start)/60} mins")
    print(results.head())
# Out:
# loss: 52.80 loss(avg): 518.71:   0%|          | 425/100000 [08:39<33:49:32,  1.22s/it]

# %% [markdown]
# ## Prediction

# %% [markdown]
# Finally we implement the inference to submit to Kaggle when **predict** param is set to True.

# %%
# ==== EVAL LOOP ================================================================
if cfg["model_params"]["predict"]:
    
    model.eval()
    torch.set_grad_enabled(False)

    # store information for evaluation
    future_coords_offsets_pd = []
    timestamps = []
    confidences_list = []
    agent_ids = []

    progress_bar = tqdm(test_dataloader)
    
    for data in progress_bar:
        
        _, preds, confidences = forward(data, model, device)
    
        #fix for the new environment
        preds = preds.cpu().numpy()
        world_from_agents = data["world_from_agent"].numpy()
        centroids = data["centroid"].numpy()
        coords_offset = []
        
        # convert into world coordinates and compute offsets
        for idx in range(len(preds)):
            for mode in range(3):
                preds[idx, mode, :, :] = transform_points(preds[idx, mode, :, :], world_from_agents[idx]) - centroids[idx][:2]
    
        future_coords_offsets_pd.append(preds.copy())
        confidences_list.append(confidences.cpu().numpy().copy())
        timestamps.append(data["timestamp"].numpy().copy())
        agent_ids.append(data["track_id"].numpy().copy())

# %%
#create submission to submit to Kaggle
pred_path = 'submission.csv'
write_pred_csv(pred_path,
           timestamps=np.concatenate(timestamps),
           track_ids=np.concatenate(agent_ids),
           coords=np.concatenate(future_coords_offsets_pd),
           confs = np.concatenate(confidences_list)
          )

# %% [markdown]
# <h3 style="color:red">That is it. Feel free to modify this kernel as you wish. Let me know your suggestions in the comments below.</h3>
# <h3 style="color:red"> Please upvote if this kernel helps you. Thanks!</h3>

# %%
# function ClickConnect()
# {
# console.log("Working");
# document.querySelector("colab-connect-button").shadowRoot.getElementById('connect').click();
# }

# setInterval(ClickConnect, 60000);
